# %%
# !pip install tqdm pandas
# Out:
# Requirement already satisfied: tqdm in /Users/AMF/opt/anaconda3/lib/python3.8/site-packages (4.65.0)
# Requirement already satisfied: pandas in /Users/AMF/opt/anaconda3/lib/python3.8/site-packages (2.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/AMF/opt/anaconda3/lib/python3.8/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/AMF/opt/anaconda3/lib/python3.8/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/AMF/opt/anaconda3/lib/python3.8/site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.20.3 in /Users/AMF/opt/anaconda3/lib/python3.8/site-packages (from pandas) (1.24.3)
# Requirement already satisfied: six>=1.5 in /Users/AMF/opt/anaconda3/lib/python3.8/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
from abc import ABC, abstractmethod
from copy import deepcopy
from tqdm import tqdm
import pandas as pd
import random
import time
import json
import os
import re

# %% [markdown]
# # Crawler

# %%
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in /Users/AMF/opt/anaconda3/lib/python3.8/site-packages (4.12.0)
# Requirement already satisfied: urllib3<3,>=1.26 in /Users/AMF/opt/anaconda3/lib/python3.8/site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.26.18)
# Requirement already satisfied: trio~=0.17 in /Users/AMF/opt/anaconda3/lib/python3.8/site-packages (from selenium) (0.22.0)
# Requirement already satisfied: trio-websocket~=0.9 in /Users/AMF/opt/anaconda3/lib/python3.8/site-packages (from selenium) (0.10.3)
# Requirement already satisfied: certifi>=2021.10.8 in /Users/AMF/opt/anaconda3/lib/python3.8/site-packages (from selenium) (2024.2.2)
# Requirement already satisfied: attrs>=19.2.0 in /Users/AMF/opt/anaconda3/lib/python3.8/site-packages (from trio~=0.17->selenium) (23.1.0)
# Requirement already satisfied: sortedcontainers in /Users/AMF/opt/anaconda3/lib/python3.8/site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: async-generator>=1.9 in /Users/AMF/opt/anaconda3/lib/python3.8/site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: idna in /Users/AMF/opt/anaconda3/lib/python3.8/site-packages (from trio~=0.17->selenium) (3.6)
# Requirement already satisfied: outcome in /Users/AMF/opt/anaconda3/lib/python3.8/site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: sniffio in /Users/AMF/opt/anaconda3/lib/python3.8/site-packages (from trio~=0.17->selenium) (1.3.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in /Users/AMF/opt/anaconda3/lib/python3.8/site-packages (from trio~=0.17->selenium) (1.1.1)
# Requirement already satisfied: wsproto>=0.14 in /Users/AMF/opt/anaconda3/lib/python3.8/site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in /Users/AMF/opt/anaconda3/lib/python3.8/site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: h11<1,>=0.9.0 in /Users/AMF/opt/anaconda3/lib/python3.8/site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.12.0)

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.common import NoSuchElementException

# %% [markdown]
# ## Crawler
# For crawling, I used [Ganjoor](https://ganjoor.net/). I crawled the poems of Ferdowsi and Khayyam.
# For Khayyam, I just crawled the Robaee poems.
# For Ferdowsi, I crawled all the poems in Shahname. I also stored the chapters of the book. So now I know which stanza belongs to which chapter.
# I chose these two poets by my own interest.
#
# **Note:** You may need to change the Safari driver to your desired web driver.

# %%
class Crawler:
    def __init__(self, main_url, starting_urls=None):
        """
        Parameters
        ----------
        main_url: str
            The main URL of the poet page. In this page there are chapters of Shahname for the Ferdowsi and Robaee, Statistics, ... for the Khayyam.
        starting_urls: list
            The starting URLs for the poet. For Ferdowsi, it is the chapters of Shahname which will be crawled automatically from the main_url. For Khayyam, it is the Robaee poems. For Khayyam, it should be provided manually and it is just one URL.
        """

        self.driver = None
        # it is a 2d list for Khayyam -> all_poems[0] = a Robaee poem, all_poems(list[0]) = 4, all_poems[0][0] = a stanza
        # it is a 3d list for Ferdowsi -> all_poems[0] = a chapter, all_poems[0][0] = a poem, all_poems[0][0][0] = a stanza
        self.all_poems = []
        # It is empty for Khayyam and it is filled for Ferdowsi
        self.chapters = []
        self.starting_urls = starting_urls
        self.main_url = main_url

    def start_driver(self):
        driver = webdriver.Safari()
        driver.maximize_window()
        self.driver = driver

    def close_driver(self):
        self.driver.close()

    def get_urls_from_poet_page(self, is_start_driver=True):
        """
        Get all the chapters (starting URLs) of the book from the main page of the poet.
        This method won't call for Khayyam because the starting URLs are provided manually.
        """

        if is_start_driver:
            self.start_driver()
        self.driver.get(self.main_url)

        all_subjects = self.driver.find_elements(By.CSS_SELECTOR, '.part-title-block a')
        all_subjects_urls = [(subject.text, subject.get_attribute('href')) for subject in all_subjects]

        if is_start_driver:
            self.close_driver()

        print(f'Number of subjects: {len(all_subjects_urls)}')
        return all_subjects_urls

    def add_chapters_and_starting_urls(self, chapter_starting_urls):
        """
        Add chapters and starting URLs for the poet (Add output of get_urls_from_poet_page method to the object).
        """

        self.chapters = []
        self.starting_urls = []

        for chapter, starting_url in chapter_starting_urls:
            self.chapters.append(chapter)
            self.starting_urls.append(starting_url)

    def get_current_poem(self):
        """
        It gets the current poem from the page.
        """

        current_poem = []
        verse_number = 1

        while True:
            try:
                current_verse = self.driver.find_element(By.ID, f'bn{verse_number}')
            except NoSuchElementException:
                break

            current_poem.append(current_verse.find_element(By.CLASS_NAME, 'm1').text)
            current_poem.append(current_verse.find_element(By.CLASS_NAME, 'm2').text)

            verse_number += 1

        return current_poem

    def get_all_poems(self, starting_url, is_start_driver=True):
        """
        Get all the poems from the starting URL. Starting URL is a chapter's URL. The method retrieves all the poems in the chapter.
        """

        if is_start_driver:
            self.start_driver()
        self.driver.get(starting_url)

        first_poem = self.driver.find_element(By.CLASS_NAME, 'poem-excerpt').find_element(By.TAG_NAME, 'a')
        next_navigation_href = first_poem.get_attribute('href')
        poet_poems = []

        progress_bar = tqdm()
        while re.search('/sh\d+', next_navigation_href):
            self.driver.get(next_navigation_href)

            current_poem = self.get_current_poem()
            poet_poems.append(current_poem)

            try:
                next_poem_button = self.driver.find_element(By.CSS_SELECTOR, '.navleft a')
            except NoSuchElementException:
                break

            next_navigation_href = next_poem_button.get_attribute('href')
            progress_bar.update(1)

        progress_bar.close()
        if is_start_driver:
            self.close_driver()
        return poet_poems

    def crawl_all_starting_urls(self, is_get_starting_urls=True):
        """
        Crawl all the poems from all starting URLs. It is the main method for crawling.
        """
        
        self.start_driver()
        self.chapters = []
        all_poems = []

        if is_get_starting_urls:
            chapter_starting_urls = self.get_urls_from_poet_page(False)
            self.add_chapters_and_starting_urls(chapter_starting_urls)

        for starting_url in self.starting_urls:
            all_poems.append(self.get_all_poems(starting_url, False))
            time.sleep(2)

        self.all_poems = all_poems[0] if len(all_poems) == 1 else all_poems
        self.close_driver()

# %% [markdown]
# ## Poet
# I created a class for the poet. It has two abstract methods. One for getting the poems from the crawler and the other for concatenating the poems for simple processing.
# I also added two methods for dumping the poems to a file and loading them from a file.

# %%
def print_file_size(file_path):
    print(f'File size: {os.path.getsize(file_path) / 1024 / 1024} MB')


class Poet(ABC):
    def __init__(self):
        self.crawler: Crawler = None
        self.all_poems = []
        # It is a 1d list for Khayyam.
        # It is a 2d list for Ferdowsi. -> concatenated_poems[0] = a chapter, concatenated_poems[0][0] = poems
        self.concatenated_poems = []
        self.chapters = []

    @abstractmethod
    def get_poems(self):
        pass

    @abstractmethod
    def concatenate_poems(self):
        pass

    def dump_poems(self, file_path):
        json.dump(self.all_poems, open(file_path, 'w'), ensure_ascii=False)
        print_file_size(file_path)

    def load_poems(self, file_path):
        self.all_poems = json.load(open(file_path, 'r'))
        print_file_size(file_path)

    @abstractmethod
    def load_all(self, file_path):
        pass

# %%
class Ferdowsi(Poet):
    def __init__(self):
        super().__init__()
        self.crawler = Crawler('https://ganjoor.net/ferdousi/shahname')

    def get_poems(self):
        self.crawler.crawl_all_starting_urls()
        self.all_poems = deepcopy(self.crawler.all_poems)
        self.chapters = deepcopy(self.crawler.chapters)

    def concatenate_poems(self):
        self.concatenated_poems = []

        for book_chapter in self.all_poems:
            book_chapter_stanzas = []

            for poem in book_chapter:
                for stanza in poem:
                    book_chapter_stanzas.append(stanza)

            self.concatenated_poems.append(book_chapter_stanzas)

    def load_all(self, file_path):
        chapter_starting_urls = self.crawler.get_urls_from_poet_page()
        self.crawler.add_chapters_and_starting_urls(chapter_starting_urls)
        self.chapters = deepcopy(self.crawler.chapters)
        self.load_poems(file_path)
        self.concatenate_poems()

# %%
class Khayyam(Poet):
    def __init__(self):
        super().__init__()
        self.crawler = Crawler('https://ganjoor.net/khayyam', ['https://ganjoor.net/khayyam/robaee'])

    def get_poems(self):
        self.crawler.crawl_all_starting_urls(False)
        self.all_poems = deepcopy(self.crawler.all_poems)
        self.chapters = deepcopy(self.crawler.chapters)

    def concatenate_poems(self):
        self.concatenated_poems = []

        for poem in self.all_poems:
            for stanza in poem:
                self.concatenated_poems.append(stanza)

    def load_all(self, file_path):
        self.crawler.chapters = []
        self.load_poems(file_path)
        self.concatenate_poems()

# %% [markdown]
# As you can see, There are 61 chapters in Shahname. Each chapter has a name. I crawled all the poems in each chapter. I stored the poems in a 3d list. The first dimension is for the chapters. The second dimension is for the poems in the chapter. The third dimension is for the stanzas in the poem.

# %%
ferdowsi = Ferdowsi()
ferdowsi.get_poems()
# Out:
# Number of subjects: 61
# 12it [00:13,  1.14s/it]
# 2it [00:02,  1.07s/it]
# 3it [00:02,  1.23it/s]
# 1it [00:01,  1.30s/it]
# 4it [00:04,  1.14s/it]
# 12it [00:12,  1.05s/it]
# 20it [00:21,  1.08s/it]
# 28it [00:34,  1.24s/it]
# 13it [00:13,  1.00s/it]
# 1it [00:01,  1.01s/it]
# 5it [00:05,  1.00s/it]
# 5it [00:05,  1.03s/it]
# 17it [00:19,  1.12s/it]
# 12it [00:13,  1.15s/it]
# 21it [00:24,  1.18s/it]
# 22it [01:05,  2.96s/it]
# 3it [00:06,  2.02s/it]
# 25it [00:26,  1.07s/it]
# 16it [00:29,  1.83s/it]
# 17it [00:26,  1.56s/it]
# 1it [00:02,  2.86s/it]
# 14it [00:22,  1.59s/it]
# 38it [00:50,  1.32s/it]
# 47it [01:02,  1.34s/it]
# 17it [00:20,  1.18s/it]
# 33it [00:37,  1.12s/it]
# 15it [00:17,  1.17s/it]
# 31it [00:35,  1.16s/it]
# 8it [00:08,  1.03s/it]
# 5it [00:04,  1.10it/s]
# 7it [00:07,  1.01s/it]
# 4it [00:03,  1.20it/s]
# 10it [00:09,  1.02it/s]
# 47it [00:46,  1.00it/s]
# 21it [00:19,  1.07it/s]
# 14it [00:15,  1.11s/it]
# 3it [00:02,  1.09it/s]
# 2it [00:02,  1.05s/it]
# 2it [00:01,  1.60it/s]
# 1it [00:00,  1.32it/s]
# 1it [00:00,  1.78it/s]
# 1it [00:00,  1.35it/s]
# 1it [00:00,  1.12it/s]
# 16it [00:16,  1.04s/it]
# 1it [00:00,  1.61it/s]
# 1it [00:00,  1.21it/s]
# 1it [00:00,  1.26it/s]
# 17it [00:15,  1.07it/s]
# 46it [00:57,  1.25s/it]
# 4it [00:13,  3.34s/it]
# 2it [00:05,  2.81s/it]
# 12it [01:06,  5.50s/it]
# 10it [00:31,  3.10s/it]
# 76it [01:34,  1.25s/it]
# 6it [00:11,  1.85s/it]
# 2it [00:02,  1.10s/it]
# 1it [00:01,  1.10s/it]
# 1it [00:00,  1.28it/s]
# 1it [00:00,  1.57it/s]
# 1it [00:00,  1.30it/s]
# 16it [00:23,  1.47s/it]

# %%
ferdowsi.concatenate_poems()

# %% [markdown]
# I dumped the poems to a file. It is JSON format. Its size in a TXT file is surely more than 1 MB, the minimum size for the crawled data.

# %%
ferdowsi.dump_poems('ferdowsi.json')
# Out:
# File size: 4.643608093261719 MB

# %% [markdown]
# You can load the Ferdowsi poems from the file by running the following cell.

# %%
ferdowsi = Ferdowsi()
ferdowsi.load_all('ferdowsi.json')
# Out:
# Number of subjects: 61
# File size: 4.643608093261719 MB

# %%
khayyam = Khayyam()
khayyam.get_poems()
# Out:
# 178it [02:41,  1.10it/s]

# %%
khayyam.concatenate_poems()

# %%
khayyam.dump_poems('khayyam.json')
# Out:
# File size: 0.038249969482421875 MB

# %% [markdown]
# You can load the Khayyam poems from the file by running the following cell.

# %%
khayyam = Khayyam()
khayyam.load_all('khayyam.json')
# Out:
# File size: 0.038249969482421875 MB

# %% [markdown]
# ## See some poems

# %%
random.seed(0)

# %% [markdown]
# In the following cell, each poem is shown with its chapter

# %%
ferdowsi_samples = []
for i, chapter in enumerate(ferdowsi.concatenated_poems):
    ferdowsi_samples.append(random.sample(chapter, 1)[0] + ' -> ' + ferdowsi.chapters[i])

print(len(ferdowsi_samples))
ferdowsi_samples
# Out:
# 61
# ['نخستین برادرش که\u200cتر به سال -> آغاز کتاب',
#  'بر آن برترین نام یزدانش را -> کیومرث',
#  'پراگند پس تخم و کشت و درود -> هوشنگ',
#  'به خوبی چه مایه سخن\u200cها براند -> طهمورث',
#  'خور و خواب و آرامتان از من است -> جمشید',
#  'وزان گرز پیکر بدیشان نمود -> ضحاک',
#  'سپه نیز با او هم آواز شد -> فریدون',
#  'کزین آگهی یافت سام سوار -> منوچهر',
#  'سرانجام نوذر گرفتار شد -> پادشاهی نوذر',
#  'ز کار گذشته نیارند یاد -> پادشاهی زوطهماسپ',
#  'از امروز و فردا نیامدش یاد -> پادشاهی گرشاسپ',
#  'فرستاده آمد بسان پلنگ -> کیقباد',
#  'جهان چون بهشتی شد آراسته -> پادشاهی کی\u200cکاووس و رفتن او به مازندران',
#  'نبد روزگار سکون و درنگ -> رزم کاووس با شاه هاماوران',
#  'به رنج و به درد و گداز آمدند -> سهراب',
#  'دل شاه کاووس ازان تنگ شد -> داستان سیاوش',
#  'سزاوار بنوشت نام گوان -> پادشاهی کیخسرو شصت سال بود',
#  'بیفتاد و برگشت زو اسپ تیز -> گفتار اندر داستان فرود سیاوش',
#  'گر ایدونک بیچاره\u200cای را زمان -> داستان کاموس کشانی',
#  'عمودی بزد بر سرش پیلتن -> داستان خاقان چین',
#  'سوی آبت اندازم ار سوی کوه -> داستان اکوان دیو',
#  'ز آهن زمین و ز سنگ آسمان -> داستان بیژن و منیژه',
#  'ز کمی و بیشی و از رنج و آز -> داستان دوازده رخ',
#  'برو دور بگزین یکی رزمگاه -> جنگ بزرگ کیخسرو با افراسیاب',
#  'سراسر بگفت آن سخنها که رفت -> پادشاهی لهراسپ',
#  'کسی کش بود نام و ماند بسی -> پادشاهی گشتاسپ صد و بیست سال بود',
#  'جهانجوی چون کار زان گونه دید -> داستان هفتخوان اسفندیار',
#  'پیاده دوانش بدین بارگاه -> داستان رستم و اسفندیار',
#  'همین بودش از رنج و ز گنج بهر -> داستان رستم و شغاد',
#  'ازو گشت ویران کنون مرز او -> پادشاهی بهمن اسفندیار صد و دوازده سال بود',
#  'ز دینار وز گوهر نابسود -> پادشاهی همای چهرزاد سی و دو سال بود',
#  'دل بدسگالان بدو نیم کرد -> پادشاهی داراب دوازده سال بود',
#  'به جان و تن از رومیان رسته\u200cاید -> پادشاهی دارای داراب چهارده سال بود',
#  'به مادر چنین گفت کهتر پسر -> پادشاهی اسکندر',
#  'به هر سو برافگند زورق به آب -> پادشاهی اشکانیان',
#  'مجوی ای پسر درد و تیمار کس -> پادشاهی اردشیر',
#  'بخوان روز و شب دفتر جمشید -> پادشاهی شاپور پسر اردشیر سی و یک سال بود',
#  'همان رسم شاپور شاه اردشیر -> پادشاهی اورمزد',
#  'چنین بود تا بود چرخ بلند -> پادشاهی بهرام اورمزد',
#  'اگر نیستت چیز لختی بورز -> پادشاهی بهرام نوزده سال بود',
#  'زمانه برین سان همی بگذرد -> پادشاهی بهرام بهرامیان',
#  'سزاوار تاجی و زیبای تخت -> پادشاهی نرسی بهرام',
#  'شود جان و مغز و دلش کاسته -> پادشاهی اورمزد نرسی',
#  'ستاره به کردار قندیل شد -> پادشاهی شاپور ذوالاکتاف',
#  'چو بنشست بر گاه شاه اردشیر -> پادشاهی اردشیر نکوکار',
#  'گواژه نباید زدن بر کسی -> پادشاهی شاپور سوم',
#  'در توبه بگزین و راه خرد -> پادشاهی بهرام شاپور',
#  'ز گیتی برآمد سراسر خروش -> پادشاهی یزدگرد بزه\u200cگر',
#  'به هریک یکی گاو داد و خری -> پادشاهی بهرام گور',
#  'سپاه پراگنده را کرد گرد -> پادشاهی یزدگرد هجده سال بود',
#  'گوا کرد زرمهر و خرداد را -> پادشاهی قباد چهل و سه سال بود',
#  'ازو دارد از کار نیکی سپاس -> پادشاهی کسری نوشین روان چهل و هشت سال بود',
#  'نهانی همی\u200cجست جای مهی -> پادشاهی هرمزد دوازده سال بود',
#  'ز مکران و بغداد و ایران زمین -> پادشاهی خسرو پرویز',
#  'پیام من اینست سوی جهان -> پادشاهی شیرویه',
#  'همه شهر ایران به خواری دهد -> پادشاهی اردشیر شیروی',
#  'برآمد شب تیره از دشت خاک -> پادشاهی فرایین',
#  'مکافات یابی ز کرده کنون -> پادشاهی پوران دخت',
#  'بیامد به تخت کیان برنشست -> پادشاهی آزرم دخت',
#  'ز گیتی هرآنکس که جوید گزند -> پادشاهی فرخ زاد',
#  'وزان جایگه جنگ لشکر بسیچ -> پادشاهی یزدگرد']

# %%
Khayyam_samples = random.sample(khayyam.concatenated_poems, len(ferdowsi_samples))
print(len(Khayyam_samples))
Khayyam_samples
# Out:
# 61
# ['در طبل زمین و حقهٔ خاک نهاد',
#  'افسوس که سرمایه ز کف بیرون شد',
#  'دریاب که هفتهٔ\xa0دگر خاک شده\u200cست',
#  'رفتم که در این منزلِ بیداد بُدَن',
#  'این کوزه\u200cگر دهر چنین جام لطیف',
#  'برخیز و به جام باده کن عزم درست',
#  'خیام ، که گفت دوزخی خواهد بود',
#  'عجز است به دست هرکه از مادر زاد',
#  'من می نه ز بهر تنگدستی نخورم',
#  'در دهر چه صد ساله چه یکروزه شویم',
#  'در بی\u200cخبری مرد چه هشیار و چه مست',
#  'دهقان قضا بسی چو ما کشت و درود',
#  'قانع به یک استخوان چو کرکس بودن',
#  'گویند قرابه\u200cگر مسلمان نبود',
#  'می خور که چنین فسانه\u200cها کوته نیست',
#  'رندی دیدم نشسته بر خنگ زمین',
#  'گر یک نفست ز زندگانی گذرد',
#  'جز خوردن غصه نیست تا کندن جان',
#  'چون عمر به سر رسد چه شیرین و چه تلخ',
#  'وین عمر به خوشدلی گذارم یا نه',
#  'خشتی دو نهند بر مغاک من و تو',
#  'کار من و تو چنان\u200cکه رای من و توست',
#  'کو بانگ جرس\u200cها و کجا ناله کوس\u200c\u200c؟',
#  'مستی و قلندری و گمراهی به',
#  'چون می\u200cدانی که مدت عالم خاک',
#  'کس مشکل اسرار اجل را نگشاد',
#  'وقت خوش خود بسنگ محنت سودن',
#  'کاحوال مسافران دنیا چون شد',
#  'همواره همو کار عدو می\u200cسازد',
#  'نیکی و بدی که در نهاد بشر است',
#  'از سرخی خون شهریاری بوده\u200cست',
#  'چرخ از تو هزار بار بیچاره\u200cتر است',
#  'دست تو ز جام می چرا بیکار است',
#  'تا عمر گرانبها بدان نفروشی',
#  'چندان که نگاه می\u200cکنم هر سویی',
#  'جان عزم رحیل کرد و گفتم بمرو',
#  'ما چون صوریم کاندر او حیرانیم',
#  'هرگز غم دو روز مرا یاد نگشت',
#  'گردی و نسیمی و غباری و دمی\u200cست',
#  'نه آمدمی نه شدمی نه بُدَمی',
#  'او را نه بدایت نه نهایت پیدا\u200cست',
#  'با یک دو سه اهل و لعبتی حور\u200cسرشت',
#  'کاین باقی عمر را بها پیدا نیست',
#  'عیشی بود آن نه حد هر سلطانی',
#  'افلاک که جز غم نفزایند دگر',
#  'یک دمزدن از وجود خود شاد نیم',
#  'گر چشمهٔ زمزمی و گر آب حیات',
#  'پایان سخن شنو که ما را چه رسید',
#  'قطره چو کشد حبس صدف در گردد',
#  'آن\u200cها که کهن شدند و این\u200cها که نوند',
#  'در کالبدی کشند خاک من و تو',
#  'سرمایه لذت جوانی است بخور',
#  'بر درگه آن شهان نهادندی رو',
#  'چند از پی هر زشت و نکو خواهی شد',
#  'با ماهرخی اگر نشستی خوش باش',
#  'چون نیست مقام ما در این دهر مقیم',
#  'خوش باش که پخته\u200cاند سودای تو دی',
#  'بر شاخ امید اگر بری یافتمی',
#  'بالای بنفشه در چمن خم گیرد',
#  'ترکیب پیاله\u200cای که در هم پیوست',
#  'گرچه غم و رنج من درازی دارد']

# %% [markdown]
# # Preprocessing

# %%
# !pip install hazm && pip install hazm --upgrade
# Out:
# Requirement already satisfied: hazm in /Users/AMF/opt/anaconda3/lib/python3.8/site-packages (0.10.0)
# Requirement already satisfied: fasttext-wheel<0.10.0,>=0.9.2 in /Users/AMF/opt/anaconda3/lib/python3.8/site-packages (from hazm) (0.9.2)
# Requirement already satisfied: flashtext<3.0,>=2.7 in /Users/AMF/opt/anaconda3/lib/python3.8/site-packages (from hazm) (2.7)
# Requirement already satisfied: gensim<5.0.0,>=4.3.1 in /Users/AMF/opt/anaconda3/lib/python3.8/site-packages (from hazm) (4.3.2)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in /Users/AMF/opt/anaconda3/lib/python3.8/site-packages (from hazm) (3.8.1)
# Requirement already satisfied: numpy==1.24.3 in /Users/AMF/opt/anaconda3/lib/python3.8/site-packages (from hazm) (1.24.3)
# Requirement already satisfied: python-crfsuite<0.10.0,>=0.9.9 in /Users/AMF/opt/anaconda3/lib/python3.8/site-packages (from hazm) (0.9.10)
# Requirement already satisfied: scikit-learn<2.0.0,>=1.2.2 in /Users/AMF/opt/anaconda3/lib/python3.8/site-packages (from hazm) (1.3.2)
# Requirement already satisfied: pybind11>=2.2 in /Users/AMF/opt/anaconda3/lib/python3.8/site-packages (from fasttext-wheel<0.10.0,>=0.9.2->hazm) (2.10.4)
# Requirement already satisfied: setuptools>=0.7.0 in /Users/AMF/opt/anaconda3/lib/python3.8/site-packages (from fasttext-wheel<0.10.0,>=0.9.2->hazm) (69.2.0)
# Requirement already satisfied: scipy>=1.7.0 in /Users/AMF/opt/anaconda3/lib/python3.8/site-packages (from gensim<5.0.0,>=4.3.1->hazm) (1.10.1)
# Requirement already satisfied: smart-open>=1.8.1 in /Users/AMF/opt/anaconda3/lib/python3.8/site-packages (from gensim<5.0.0,>=4.3.1->hazm) (5.2.1)
# Requirement already satisfied: click in /Users/AMF/opt/anaconda3/lib/python3.8/site-packages (from nltk<4.0.0,>=3.8.1->hazm) (8.1.3)
# Requirement already satisfied: joblib in /Users/AMF/opt/anaconda3/lib/python3.8/site-packages (from nltk<4.0.0,>=3.8.1->hazm) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in /Users/AMF/opt/anaconda3/lib/python3.8/site-packages (from nltk<4.0.0,>=3.8.1->hazm) (2023.10.3)
# Requirement already satisfied: tqdm in /Users/AMF/opt/anaconda3/lib/python3.8/site-packages (from nltk<4.0.0,>=3.8.1->hazm) (4.65.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/AMF/opt/anaconda3/lib/python3.8/site-packages (from scikit-learn<2.0.0,>=1.2.2->hazm) (3.1.0)
# Requirement already satisfied: hazm in /Users/AMF/opt/anaconda3/lib/python3.8/site-packages (0.10.0)
# Requirement already satisfied: fasttext-wheel<0.10.0,>=0.9.2 in /Users/AMF/opt/anaconda3/lib/python3.8/site-packages (from hazm) (0.9.2)
# Requirement already satisfied: flashtext<3.0,>=2.7 in /Users/AMF/opt/anaconda3/lib/python3.8/site-packages (from hazm) (2.7)
# Requirement already satisfied: gensim<5.0.0,>=4.3.1 in /Users/AMF/opt/anaconda3/lib/python3.8/site-packages (from hazm) (4.3.2)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in /Users/AMF/opt/anaconda3/lib/python3.8/site-packages (from hazm) (3.8.1)
# Requirement already satisfied: numpy==1.24.3 in /Users/AMF/opt/anaconda3/lib/python3.8/site-packages (from hazm) (1.24.3)
# Requirement already satisfied: python-crfsuite<0.10.0,>=0.9.9 in /Users/AMF/opt/anaconda3/lib/python3.8/site-packages (from hazm) (0.9.10)
# Requirement already satisfied: scikit-learn<2.0.0,>=1.2.2 in /Users/AMF/opt/anaconda3/lib/python3.8/site-packages (from hazm) (1.3.2)
# Requirement already satisfied: pybind11>=2.2 in /Users/AMF/opt/anaconda3/lib/python3.8/site-packages (from fasttext-wheel<0.10.0,>=0.9.2->hazm) (2.10.4)
# Requirement already satisfied: setuptools>=0.7.0 in /Users/AMF/opt/anaconda3/lib/python3.8/site-packages (from fasttext-wheel<0.10.0,>=0.9.2->hazm) (69.2.0)
# Requirement already satisfied: scipy>=1.7.0 in /Users/AMF/opt/anaconda3/lib/python3.8/site-packages (from gensim<5.0.0,>=4.3.1->hazm) (1.10.1)
# Requirement already satisfied: smart-open>=1.8.1 in /Users/AMF/opt/anaconda3/lib/python3.8/site-packages (from gensim<5.0.0,>=4.3.1->hazm) (5.2.1)
# Requirement already satisfied: click in /Users/AMF/opt/anaconda3/lib/python3.8/site-packages (from nltk<4.0.0,>=3.8.1->hazm) (8.1.3)
# Requirement already satisfied: joblib in /Users/AMF/opt/anaconda3/lib/python3.8/site-packages (from nltk<4.0.0,>=3.8.1->hazm) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in /Users/AMF/opt/anaconda3/lib/python3.8/site-packages (from nltk<4.0.0,>=3.8.1->hazm) (2023.10.3)
# Requirement already satisfied: tqdm in /Users/AMF/opt/anaconda3/lib/python3.8/site-packages (from nltk<4.0.0,>=3.8.1->hazm) (4.65.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/AMF/opt/anaconda3/lib/python3.8/site-packages (from scikit-learn<2.0.0,>=1.2.2->hazm) (3.1.0)

# %%
from hazm import *

# %% [markdown]
# ## Preprocessor
# I created a preprocessor class for preprocessing the poems. It has the following methods:
# - normalize: It normalizes the text.
# - lemmatize: It lemmatizes the word.
# - tokenize: It tokenizes the text.
# - preprocess: It normalizes, tokenizes, and lemmatizes the text.
# - find_stopwords: It finds the stopwords in the text. It sets stopwords_count which is a dictionary of words and their counts. It also sets stopwords which is a list of stopwords. It runs on output of preprocess method.
# - remove_stopwords: It removes the stopwords from the text.

# %%
class Preprocessor:
    def __init__(self):
        self.normalizer = Normalizer()
        self.lemmatizer = Lemmatizer()
        self.word_tokenizer = WordTokenizer()

        self.stopwords_count = {}
        self.stopwords = []

    def normalize(self, text):
        return self.normalizer.normalize(text)

    def lemmatize(self, word):
        return self.lemmatizer.lemmatize(word)

    def tokenize(self, text):
        return self.word_tokenizer.tokenize(text)

    def preprocess(self, poem: list):
        preprocessed_text = []

        for stanza in poem:
            normalized_stanza = self.normalize(stanza)
            tokenized_stanza = self.tokenize(normalized_stanza)
            preprocessed_stanza = [self.lemmatize(word) for word in tokenized_stanza]

            preprocessed_text.append(preprocessed_stanza)

        return preprocessed_text

    def find_stopwords(self, poem: list):
        self.stopwords_count = {}

        for stanza in poem:
            for word in stanza:
                if word in self.stopwords_count:
                    self.stopwords_count[word] += 1
                else:
                    self.stopwords_count[word] = 1

        self.stopwords_count = list(sorted(self.stopwords_count.items(), key=lambda x: x[1], reverse=True))
        self.stopwords = [word for word, _ in self.stopwords_count]

    def remove_stopwords(self, text: list, number_of_stopwords=10):
        return [[word for word in stanza if word not in self.stopwords[:number_of_stopwords]] for stanza in text]


def run_preprocess(poem, is_print=True):
    """
    It runs a preprocess the poem. The poem should be a 1d list. It returns the preprocessed dataframe and the preprocessor object.
    The dataframe contains the original, preprocessed, and preprocessed_no_stopwords columns.
    And we need the preprocessor object to access the stopwords and stopwords_count.
    """
    
    dataframe = pd.DataFrame(poem, columns=['original'])
    preprocessor = Preprocessor()

    preprocessed = preprocessor.preprocess(poem)
    dataframe['preprocessed'] = preprocessed

    preprocessor.find_stopwords(preprocessed)
    preprocessed_no_stopwords = preprocessor.remove_stopwords(preprocessed)
    dataframe['preprocessed_no_stopwords'] = preprocessed_no_stopwords

    if is_print:
        print(preprocessor.stopwords_count[:200])
        print(preprocessor.stopwords[:10])
    return dataframe, preprocessor

# %% [markdown]
# ## Preprocess the poems of Khayyam
# In the output of the following cell, you can see the stopwords_count and the top 10 stopwords.
# Then, there's a dataframe for comparing the original, preprocessed, and preprocessed_no_stopwords.
#
# As you can see in the first row, the word 'ز' is removed in the preprocessed_no_stopwords column. Or in the third row, we can see the word 'کنیم' is lemmitized.

# %%
khayyam_dataframe, khayyam_preprocessor = run_preprocess(khayyam.concatenated_poems)
khayyam_dataframe.head(10)
# Out:
# [('و', 230), ('که', 185), ('به', 122), ('از', 95), ('در', 84), ('ز', 69), ('تو', 55), ('است', 54), ('این', 51), ('بر', 51), ('من', 50), ('را', 48), ('شد#شو', 45), ('آن', 36), ('چه', 36), ('تا', 33), ('هر', 32), ('چو', 32), ('خاک', 32), ('چون', 31), ('بود#است', 31), ('با', 31), ('یک', 29), ('کرد#کن', 29), ('نه', 29), ('ما', 27), ('دل', 26), ('خوش', 24), ('گل', 22), ('آمد#آ', 21), ('نیست', 21), ('گفت#گو', 21), ('دست', 20), ('خورد#خور', 19), ('عمر', 19), ('سر', 18), ('جهان', 18), ('همه', 17), ('باده', 17), ('او', 16), ('سبزه', 16), ('دانست#دان', 16), ('کوزه', 15), ('گر', 15), ('دید#بین', 15), ('ای', 15), ('کس', 15), ('غم', 15), ('رفت#رو', 14), ('اگر', 14), ('دو', 14), ('باشید#باش', 14), ('پیش', 13), ('مکن', 13), ('چند', 13), ('مرا', 13), ('جام', 13), ('باش', 13), ('چرخ', 13), ('دی', 13), ('بهشت', 13), ('داشت#دار', 13), ('یا', 13), ('صد', 12), ('فلک', 12), ('زمین', 12), ('خود', 12), ('بوده\u200cست', 11), ('؟', 11), ('گدشت#گذر', 11), ('هم', 10), ('پر', 10), ('می\u200cنوش', 10), ('باز', 10), ('می\u200cخور', 10), ('جز', 10), ('عالم', 10), ('گفت#گوی', 10), ('اندر', 10), ('هیچ', 10), ('وز', 10), ('کار', 10), ('کسی', 9), ('فردا', 9), ('بسیار', 9), ('جان', 9), ('باد', 9), ('گرفت#گیر', 9), ('بی', 9), ('روزید#روز', 9), ('روی', 9), ('کم', 9), ('اجل', 9), ('دگر', 9), ('بدی', 9), ('هزار', 9), ('کی', 9), ('بهر', 8), ('کن', 8), ('هست', 8), ('زمانه', 8), ('کاین', 8), ('کف', 8), ('گشت#گرد', 8), ('نتوان', 8), ('آمدن', 8), ('داد#ده', 8), ('ماند#مان', 8), ('کوزه\u200cگر', 8), ('رخ', 7), ('می\u200cو', 7), ('امید', 7), ('آب', 7), ('روز', 7), ('لب', 7), ('شاد', 7), ('قدح', 7), ('نهاد#نه', 7), ('رفتن', 7), ('ساقی', 7), ('دهر', 7), ('بار', 7), ('رسید#رس', 7), ('خویش', 7), ('زان', 7), ('شراب', 6), ('سودا', 6), ('پیاله', 6), ('فارغ', 6), ('امروز', 6), ('کجا', 6), ('تن', 6), ('،', 6), ('مست', 6), ('گیر', 6), ('اسرار', 6), ('ره', 6), ('خواب', 6), ('دمی', 6), ('برد#بر', 6), ('دور', 6), ('بسید#بس', 6), ('مخور', 6), ('خور', 6), ('کو', 6), ('برخیز', 5), ('لاله', 5), ('گور', 5), ('بایست#بای', 5), ('شده', 5), ('توس', 5), ('بس', 5), ('بیرون', 5), ('بند', 5), ('مستی', 5), ('نام', 5), ('گذشت#گذر', 5), ('خشت', 5), ('اهل', 5), ('راه', 5), ('دریاب', 5), ('باید', 5), ('هرچه', 5), ('زیر', 5), ('زین', 5), ('بودن', 5), ('دین', 5), ('خون', 5), ('نهاد', 5), ('قضا', 5), ('عقل', 5), ('جرعه', 5), ('لعل', 5), ('افسوس', 5), ('بخور', 5), ('مشکل', 4), ('زآن', 4), ('ماه', 4), ('خواند#خوان', 4), ('گرد', 4), ('کاندر', 4), ('رنگ', 4), ('آزاد', 4), ('ابر', 4), ('چنین', 4), ('دم', 4), ('هفت', 4), ('ناگه', 4), ('بزی', 4), ('وجود', 4), ('نیز', 4), ('چشم', 4), ('زد#زن', 4), ('دوزخ', 4), ('پای', 4), ('رو', 4), ('خرد', 4), ('یافت#یاب', 4), ('حال', 4), ('یقین', 4)]
# ['و', 'که', 'به', 'از', 'در', 'ز', 'تو', 'است', 'این', 'بر']
#                            original  \
# 0         برخیز بتا بیا ز بهر دل ما
# 1      حل کن به جمال خویشتن مشکل ما
# 2    یک کوزه شراب تا به هم نوش کنیم
# 3  زآن پیش که کوزه‌ها کنند از گل ما
# 4      چون عهده نمی‌شود کسی فردا را
# 5    حالی خوش دار این دل پر سودا را
# 6    می نوش به ماهتاب ای ماه که ماه
# 7         بسیار بتابد و نیابد ما را
# 8    قرآن که مهین کلام خوانند آن را
# 9     گهگاه نه بر دوام خوانند آن را
#
#                                  preprocessed  \
# 0           [برخیز, بتا, بیا, ز, بهر, دل, ما]
# 1        [حل, کن, به, جمال, خویشتن, مشکل, ما]
# 2   [یک, کوزه, شراب, تا, به, هم, نوش, کرد#کن]
# 3    [زآن, پیش, که, کوزه, کرد#کن, از, گل, ما]
# 4           [چون, عهده, شد#شو, کسی, فردا, را]
# 5     [حالی, خوش, دار, این, دل, پر, سودا, را]
# 6          [می‌نوش, به, ماهتاب, ماه, که, ماه]
# 7     [بسیار, تافت#تاب, و, یابید#یاب, ما, را]
# 8  [قرآن, که, مهین, کلام, خواند#خوان, آن, را]
# 9   [گهگاه, نه, بر, دوام, خواند#خوان, آن, را]
#
#                 preprocessed_no_stopwords
# 0          [برخیز, بتا, بیا, بهر, دل, ما]
# 1        [حل, کن, جمال, خویشتن, مشکل, ما]
# 2   [یک, کوزه, شراب, تا, هم, نوش, کرد#کن]
# 3        [زآن, پیش, کوزه, کرد#کن, گل, ما]
# 4       [چون, عهده, شد#شو, کسی, فردا, را]
# 5      [حالی, خوش, دار, دل, پر, سودا, را]
# 6              [می‌نوش, ماهتاب, ماه, ماه]
# 7    [بسیار, تافت#تاب, یابید#یاب, ما, را]
# 8  [قرآن, مهین, کلام, خواند#خوان, آن, را]
# 9   [گهگاه, نه, دوام, خواند#خوان, آن, را]

# %% [markdown]
# ## Preprocess the poems of Ferdowsi (All)
# First, I concatenated all the poems of Ferdowsi into a single 1d list.
# In the output of the following cell, you can see the stopwords_count and the top 10 stopwords.
# Then, there's a dataframe for comparing the original, preprocessed, and preprocessed_no_stopwords.
#
# As you can see in the first row, the word 'و' is removed in the preprocessed_no_stopwords column. Or in the second row, we can see the word 'نگذرد' is lemmitized.

# %%
all_ferdowsi = []
for chapter in ferdowsi.concatenated_poems:
    all_ferdowsi.extend(chapter)

all_ferdowsi_dataframe, all_ferdowsi_preprocessor = run_preprocess(all_ferdowsi)
all_ferdowsi_dataframe.head(10)
# Out:
# [('و', 24138), ('به', 17809), ('که', 12569), ('ز', 12017), ('از', 10540), ('بر', 8330), ('را', 7676), ('چو', 6423), ('شد#شو', 5475), ('گفت#گو', 5471), ('با', 4663), ('شاه', 4302), ('بود#است', 4233), ('کرد#کن', 4174), ('تو', 4072), ('همی', 3943), ('او', 3812), ('آمد#آ', 3770), ('آن', 3656), ('یکی', 3389), ('همه', 3253), ('اندر', 2960), ('من', 2876), ('در', 2739), ('سر', 2727), ('تا', 2651), ('پیش', 2554), ('این', 2543), ('چنین', 2512), ('دل', 2482), ('بد', 2154), ('پر', 2059), ('بدو', 2031), ('هر', 2017), ('جهان', 1939), ('سپاه', 1837), ('داد', 1794), ('چون', 1791), ('سخن', 1766), ('پس', 1723), ('دو', 1695), ('نه', 1645), ('لشکر', 1637), ('دید#بین', 1572), ('راه', 1553), ('سوی', 1534), ('کار', 1525), ('روی', 1515), ('تخت', 1482), ('داشت#دار', 1460), ('چه', 1456), ('ما', 1404), ('باشید#باش', 1382), ('جنگ', 1374), ('جای', 1315), ('مرد', 1301), ('مرا', 1267), ('گرد', 1262), ('دست', 1257), ('گشت', 1207), ('ماند#مان', 1200), ('بیامد', 1199), ('هم', 1197), ('همان', 1192), ('زمین', 1153), ('آورد#آور', 1153), ('ایران', 1150), ('باد', 1140), ('بدان', 1095), ('کس', 1090), ('روز', 1086), ('شهریار', 1076), ('کسی', 1074), ('یک', 1068), ('بدین', 1067), ('خویش', 1050), ('نام', 1012), ('تاج', 1012), ('خون', 999), ('گنج', 998), ('خواند#خوان', 990), ('اگر', 990), ('نزدیک', 988), ('تن', 986), ('اوی', 974), ('گشت#گرد', 965), ('رای', 959), ('گرفت#گیر', 958), ('رنج', 944), ('نیست', 885), ('کنون', 876), ('آب', 863), ('ازان', 853), ('کوه', 852), ('کین', 829), ('زین', 821), ('نیز', 818), ('دید', 813), ('چنان', 812), ('میان', 811), ('بران', 807), ('گیتی', 805), ('رستم', 805), ('نامدار', 802), ('رفت#رو', 800), ('جز', 792), ('پاسخ', 787), ('اندرون', 784), ('زان', 769), ('خرد', 768), ('شیر', 763), ('آفرین', 763), ('دگر', 751), ('شب', 746), ('برو', 739), ('یزدان', 735), ('درد', 728), ('بهرام', 723), ('بسید#بس', 720), ('جان', 719), ('باید', 712), ('شاد', 711), ('خاک', 710), ('ترا', 706), ('دشت', 703), ('نامه', 698), ('کجا', 696), ('گفتار', 693), ('دانست#دان', 688), ('وز', 683), ('زمان', 675), ('یاد', 673), ('سپه', 673), ('پیل', 657), ('فرستاد#فرست', 656), ('پای', 642), ('پدر', 642), ('روان', 640), ('ماه', 637), ('کای', 634), ('کز', 632), ('روزگار', 628), ('بفرمود', 625), ('برآمد', 624), ('باز', 618), ('برد#بر', 612), ('برین', 610), ('شهر', 606), ('خسرو', 604), ('مگر', 603), ('تیره', 596), ('بهر', 595), ('مهر', 589), ('کند', 589), ('بشنید', 581), ('خود', 573), ('پهلوان', 572), ('جهاندار', 569), ('یابید#یاب', 566), ('انجمن', 566), ('فرمان', 562), ('تیغ', 562), ('خورشید', 556), ('پشت', 551), ('گاه', 547), ('گردان', 545), ('نامور', 534), ('ورا', 526), ('دلیر', 526), ('رزم', 525), ('داد#ده', 523), ('بدی', 514), ('بخت', 512), ('موبد', 505), ('کردار', 499), ('چین', 499), ('بلند', 498), ('کن', 491), ('سوار', 490), ('پاک', 481), ('بزرگان', 479), ('است', 475), ('نبرد', 473), ('ازین', 473), ('نهاد#نه', 467), ('برفتند', 465), ('کلاه', 464), ('نهان', 462), ('بند', 461), ('بوم', 460), ('راست', 457), ('رسید', 457), ('نزد', 456), ('دریا', 452), ('گیو', 447), ('وزان', 442), ('خواب', 441), ('نگه', 441), ('نشست', 441), ('گونه', 440)]
# ['و', 'به', 'که', 'ز', 'از', 'بر', 'را', 'چو', 'شد#شو', 'گفت#گو']
#                        original                           preprocessed  \
# 0       به نام خداوند جان و خرد         [به, نام, خداوند, جان, و, خرد]
# 1   کز این برتر اندیشه بر نگذرد  [کز, این, برتر, اندیشه, بر, گدشت#گذر]
# 2       خداوند نام و خداوند جای          [خداوند, نام, و, خداوند, جای]
# 3         خداوند روزی ده رهنمای              [خداوند, روزی‌ده, رهنمای]
# 4    خداوند کیوان و گَردان سپهر        [خداوند, کیوان, و, گردان, سپهر]
# 5    فروزندهٔ ماه و ناهید و مهر       [فروزنده, ماه, و, ناهید, و, مهر]
# 6  ز نام و نشان و گمان برتر است  [ز, نام, و, نشان, و, گمان, برتر, است]
# 7      نگارندهٔ بر شده پیکر است          [نگارنده, بر, شده, پیکر, است]
# 8       به بینندگان آفریننده را           [به, بینندگان, آفریننده, را]
# 9     نبینی مرنجان دو بیننده را        [دید#بین, مرنج, دو, بیننده, را]
#
#            preprocessed_no_stopwords
# 0            [نام, خداوند, جان, خرد]
# 1  [کز, این, برتر, اندیشه, گدشت#گذر]
# 2         [خداوند, نام, خداوند, جای]
# 3          [خداوند, روزی‌ده, رهنمای]
# 4       [خداوند, کیوان, گردان, سپهر]
# 5         [فروزنده, ماه, ناهید, مهر]
# 6       [نام, نشان, گمان, برتر, است]
# 7          [نگارنده, شده, پیکر, است]
# 8               [بینندگان, آفریننده]
# 9        [دید#بین, مرنج, دو, بیننده]

# %% [markdown]
# ## Preprocess the poems of Ferdowsi (Chapter Base)
# First, I preprocessed the poems of each chapter separately.
# In the output of the following cell, you can see the stopwords (count more than 10) of each chapter.
# Then, there's a dataframe for comparing the stopwords of each chapter (all stopwords and top 20).
#
# Finally finding in common stopwords of all chapters (more accurately, chapters with more than 10 stopwords).

# %%
ferdowsi_dataframes = []
ferdowsi_preprocessors = []

progress_bar = tqdm(ferdowsi.concatenated_poems, desc='Ferdowsi, Shahname Chapters Preprocessing')
for chapter in progress_bar:
    ferdowsi_dataframe, ferdowsi_preprocessor = run_preprocess(chapter, False)
    ferdowsi_dataframes.append(ferdowsi_dataframe)
    ferdowsi_preprocessors.append(ferdowsi_preprocessor)
    
    
ferdowsi_stopwords_chapter_based = []
for ferdowsi_preprocessor in ferdowsi_preprocessors:
    ferdowsi_stopwords_chapter_based.append([ferdowsi_preprocessor.stopwords for ferdowsi_preprocessor.stopwords, count in ferdowsi_preprocessor.stopwords_count if count > 10])
# Out:
# Ferdowsi, Shahname Chapters Preprocessing: 100%|██████████| 61/61 [03:24<00:00,  3.36s/it]

# %% [markdown]
# In the output of the following cell, as we can see, there are some common stopwords such as 'و' and 'به' and 'از'.

# %%
dataframe = pd.DataFrame()
for i in range(len(ferdowsi_stopwords_chapter_based)):
    dataframe[f'chapter_{i + 1}, {ferdowsi.chapters[i]}'] = pd.Series(ferdowsi_stopwords_chapter_based[i])

dataframe
# Out:
#    chapter_1, آغاز کتاب chapter_2, کیومرث chapter_3, هوشنگ chapter_4, طهمورث  \
# 0                     و                 و                و                به
# 1                    به                به           کرد#کن                 و
# 2                    از                بر               به                را
# 3                    بر                را               از                او
# 4                     ز                که              NaN                بر
# 5                    که                از              NaN                از
# 6                    را                او              NaN               NaN
# 7                    او           بود#است              NaN               NaN
# 8                    چو                آن              NaN               NaN
# 9                   این                 ز              NaN               NaN
# 10              بود#است               NaN              NaN               NaN
# 11                  است               NaN              NaN               NaN
# 12                  همی               NaN              NaN               NaN
# 13                   هر               NaN              NaN               NaN
# 14                  خرد               NaN              NaN               NaN
# 15                شد#شو               NaN              NaN               NaN
# 16                   آن               NaN              NaN               NaN
# 17                 جهان               NaN              NaN               NaN
# 18                  سخن               NaN              NaN               NaN
# 19                آمد#آ               NaN              NaN               NaN
# 20                   چه               NaN              NaN               NaN
# 21                  یکی               NaN              NaN               NaN
# 22               گفت#گو               NaN              NaN               NaN
# 23               خداوند               NaN              NaN               NaN
# 24                   در               NaN              NaN               NaN
# 25                 اندر               NaN              NaN               NaN
# 26                   تو               NaN              NaN               NaN
# 27                   من               NaN              NaN               NaN
# 28                   سر               NaN              NaN               NaN
# 29                   نه               NaN              NaN               NaN
# 30                 نامه               NaN              NaN               NaN
# 31                   دل               NaN              NaN               NaN
# 32             داشت#دار               NaN              NaN               NaN
# 33                  چون               NaN              NaN               NaN
# 34                  شاه               NaN              NaN               NaN
# 35                  جان               NaN              NaN               NaN
# 36                  راه               NaN              NaN               NaN
#
#    chapter_5, جمشید chapter_6, ضحاک chapter_7, فریدون chapter_8, منوچهر  \
# 0                 و              به                 و                 و
# 1                به               و                به                به
# 2                از              که                از                از
# 3                 ز              از                 ز                که
# 4                را               ز                که                بر
# 5                چو              بر                را                 ز
# 6                بر              را                چو                را
# 7                او              آن                بر                چو
# 8            کرد#کن              چو               شاه             شد#شو
# 9                که         بود#است             شد#شو            گفت#گو
# 10               آن              او            کرد#کن                با
# 11          بود#است              تو            گفت#گو               یکی
# 12              بدو            ضحاک                آن                تو
# 13           گفت#گو             یکی               همه               سام
# 14              این           شد#شو                با             آمد#آ
# 15               هر          گفت#گو                سر               همی
# 16              یکی            اندر             آمد#آ                من
# 17            شد#شو           آمد#آ              اندر                او
# 18             جهان              سر                هر            کرد#کن
# 19             اندر             همی                دل           بود#است
# 20               من            جهان               یکی                آن
# 21               چه              با               پیش                دل
# 22               با              دو                دو              اندر
# 23               تو              من               همی               زال
# 24               بد          فریدون           بود#است               همه
# 25            آمد#آ             پیش               چون                تا
# 26              تخت             شاه                من                سر
# 27              همه             همه               تخت               این
# 28              شاه              بد                سه               شاه
# 29              NaN              در                او               پیش
# 30              NaN              هر               روی               چون
# 31              NaN          کرد#کن                پر                هر
# 32              NaN              تا                در                پر
# 33              NaN             بدو                چه               روی
# 34              NaN             دست                نه                در
# 35              NaN             تخت               تاج              چنین
# 36              NaN              پر              جهان               داد
#
#    chapter_9, پادشاهی نوذر chapter_10, پادشاهی زوطهماسپ  ...  \
# 0                       به                            و  ...
# 1                        و                            ز  ...
# 2                       که                           به  ...
# 3                        ز                          NaN  ...
# 4                       از                          NaN  ...
# 5                    شد#شو                          NaN  ...
# 6                       چو                          NaN  ...
# 7                       را                          NaN  ...
# 8                       بر                          NaN  ...
# 9                       با                          NaN  ...
# 10                   آمد#آ                          NaN  ...
# 11                     همی                          NaN  ...
# 12                  کرد#کن                          NaN  ...
# 13                      سر                          NaN  ...
# 14                  گفت#گو                          NaN  ...
# 15                     یکی                          NaN  ...
# 16                    اندر                          NaN  ...
# 17                     شاه                          NaN  ...
# 18                 بود#است                          NaN  ...
# 19                     روی                          NaN  ...
# 20                    نوذر                          NaN  ...
# 21                      دل                          NaN  ...
# 22                     سوی                          NaN  ...
# 23                    لشکر                          NaN  ...
# 24                    قارن                          NaN  ...
# 25                     همه                          NaN  ...
# 26                    سپاه                          NaN  ...
# 27                      آن                          NaN  ...
# 28                     جنگ                          NaN  ...
# 29                      در                          NaN  ...
# 30                      پر                          NaN  ...
# 31                      تا                          NaN  ...
# 32                     پیش                          NaN  ...
# 33                      او                          NaN  ...
# 34                     گرد                          NaN  ...
# 35                     چون                          NaN  ...
# 36                افراسیاب                          NaN  ...
#
#    chapter_52, پادشاهی کسری نوشین روان چهل و هشت سال بود  \
# 0                                                   و
# 1                                                  که
# 2                                                  به
# 3                                                   ز
# 4                                                  از
# 5                                                  را
# 6                                                 شاه
# 7                                                  بر
# 8                                             بود#است
# 9                                                  با
# 10                                             گفت#گو
# 11                                              شد#شو
# 12                                                 چو
# 13                                                 او
# 14                                                همه
# 15                                             کرد#کن
# 16                                               چنین
# 17                                                داد
# 18                                                 دل
# 19                                                یکی
# 20                                              آمد#آ
# 21                                                 تو
# 22                                                 در
# 23                                                سخن
# 24                                                 آن
# 25                                                پیش
# 26                                          باشید#باش
# 27                                                 بد
# 28                                               اندر
# 29                                                 تا
# 30                                           داشت#دار
# 31                                                 سر
# 32                                               جهان
# 33                                                مرد
# 34                                                 هر
# 35                                                این
# 36                                               پاسخ
#
#    chapter_53, پادشاهی هرمزد دوازده سال بود chapter_54, پادشاهی خسرو پرویز  \
# 0                                        که                              و
# 1                                         و                             که
# 2                                        به                             به
# 3                                        را                              ز
# 4                                         ز                             از
# 5                                        از                             را
# 6                                       شاه                         گفت#گو
# 7                                    گفت#گو                             بر
# 8                                     شد#شو                          شد#شو
# 9                                        بر                             چو
# 10                                  بود#است                        بود#است
# 11                                       آن                             تو
# 12                                       تو                             آن
# 13                                       چو                         کرد#کن
# 14                                       با                             با
# 15                                   کرد#کن                            شاه
# 16                                    بهرام                             او
# 17                                       تا                            یکی
# 18                                    آمد#آ                             تا
# 19                                      یکی                          آمد#آ
# 20                                       پس                            همه
# 21                                     سپاه                           خسرو
# 22                                       در                            سخن
# 23                                       بد                             در
# 24                                       من                            بدو
# 25                                     چنین                           اندر
# 26                                       او                           چنین
# 27                                      پیش                            این
# 28                                      راه                             بد
# 29                                      این                          بهرام
# 30                                      همه                             من
# 31                                     اندر                             دل
# 32                                      بدو                            پیش
# 33                                     لشکر                             پس
# 34                                      همی                           همان
# 35                                      سخن                           سپاه
# 36                                      جنگ                            مرد
#
#    chapter_55, پادشاهی شیرویه chapter_56, پادشاهی اردشیر شیروی  \
# 0                           و                                و
# 1                          به                               به
# 2                          که                               که
# 3                           ز                                ز
# 4                          از                            شد#شو
# 5                          را                              NaN
# 6                          تو                              NaN
# 7                          بر                              NaN
# 8                          چو                              NaN
# 9                          آن                              NaN
# 10                    بود#است                              NaN
# 11                     گفت#گو                              NaN
# 12                        همه                              NaN
# 13                         او                              NaN
# 14                         بد                              NaN
# 15                         من                              NaN
# 16                      شد#شو                              NaN
# 17                        شاه                              NaN
# 18                         در                              NaN
# 19                     کرد#کن                              NaN
# 20                        این                              NaN
# 21                       جهان                              NaN
# 22                         هر                              NaN
# 23                       بدان                              NaN
# 24                        کجا                              NaN
# 25                        سخن                              NaN
# 26                        پیش                              NaN
# 27                       چنین                              NaN
# 28                         ما                              NaN
# 29                         تا                              NaN
# 30                         سر                              NaN
# 31                        یکی                              NaN
# 32                         پر                              NaN
# 33                         دو                              NaN
# 34                      آمد#آ                              NaN
# 35                        نیز                              NaN
# 36                  باشید#باش                              NaN
#
#    chapter_57, پادشاهی فرایین chapter_58, پادشاهی پوران دخت  \
# 0                          به                            به
# 1                          از                           NaN
# 2                          که                           NaN
# 3                          را                           NaN
# 4                           و                           NaN
# 5                         NaN                           NaN
# 6                         NaN                           NaN
# 7                         NaN                           NaN
# 8                         NaN                           NaN
# 9                         NaN                           NaN
# 10                        NaN                           NaN
# 11                        NaN                           NaN
# 12                        NaN                           NaN
# 13                        NaN                           NaN
# 14                        NaN                           NaN
# 15                        NaN                           NaN
# 16                        NaN                           NaN
# 17                        NaN                           NaN
# 18                        NaN                           NaN
# 19                        NaN                           NaN
# 20                        NaN                           NaN
# 21                        NaN                           NaN
# 22                        NaN                           NaN
# 23                        NaN                           NaN
# 24                        NaN                           NaN
# 25                        NaN                           NaN
# 26                        NaN                           NaN
# 27                        NaN                           NaN
# 28                        NaN                           NaN
# 29                        NaN                           NaN
# 30                        NaN                           NaN
# 31                        NaN                           NaN
# 32                        NaN                           NaN
# 33                        NaN                           NaN
# 34                        NaN                           NaN
# 35                        NaN                           NaN
# 36                        NaN                           NaN
#
#    chapter_59, پادشاهی آزرم دخت chapter_60, پادشاهی فرخ زاد  \
# 0                           NaN                         NaN
# 1                           NaN                         NaN
# 2                           NaN                         NaN
# 3                           NaN                         NaN
# 4                           NaN                         NaN
# 5                           NaN                         NaN
# 6                           NaN                         NaN
# 7                           NaN                         NaN
# 8                           NaN                         NaN
# 9                           NaN                         NaN
# 10                          NaN                         NaN
# 11                          NaN                         NaN
# 12                          NaN                         NaN
# 13                          NaN                         NaN
# 14                          NaN                         NaN
# 15                          NaN                         NaN
# 16                          NaN                         NaN
# 17                          NaN                         NaN
# 18                          NaN                         NaN
# 19                          NaN                         NaN
# 20                          NaN                         NaN
# 21                          NaN                         NaN
# 22                          NaN                         NaN
# 23                          NaN                         NaN
# 24                          NaN                         NaN
# 25                          NaN                         NaN
# 26                          NaN                         NaN
# 27                          NaN                         NaN
# 28                          NaN                         NaN
# 29                          NaN                         NaN
# 30                          NaN                         NaN
# 31                          NaN                         NaN
# 32                          NaN                         NaN
# 33                          NaN                         NaN
# 34                          NaN                         NaN
# 35                          NaN                         NaN
# 36                          NaN                         NaN
#
#    chapter_61, پادشاهی یزدگرد
# 0                           و
# 1                          به
# 2                          که
# 3                           ز
# 4                          از
# 5                          بر
# 6                          را
# 7                       شد#شو
# 8                          چو
# 9                       آمد#آ
# 10                         تو
# 11                         با
# 12                        شاه
# 13                     گفت#گو
# 14                     کرد#کن
# 15                    بود#است
# 16                         نه
# 17                         او
# 18                        این
# 19                         آن
# 20                         در
# 21                        یکی
# 22                        همی
# 23                       اندر
# 24                         تا
# 25                      ماهوی
# 26                        همه
# 27                         ما
# 28                         سر
# 29                       سپاه
# 30                       جهان
# 31                       چنین
# 32                        تخت
# 33                         دل
# 34                         پر
# 35                         دو
# 36                        پیش
#
# [37 rows x 61 columns]

# %%
dataframe_top_20 = pd.DataFrame()
for i in range(len(ferdowsi_stopwords_chapter_based)):
    dataframe_top_20[f'chapter_{i + 1}, {ferdowsi.chapters[i]}'] = pd.Series(ferdowsi_stopwords_chapter_based[i][:20])
    
dataframe_top_20
# Out:
#    chapter_1, آغاز کتاب chapter_2, کیومرث chapter_3, هوشنگ chapter_4, طهمورث  \
# 0                     و                 و                و                به
# 1                    به                به           کرد#کن                 و
# 2                    از                بر               به                را
# 3                    بر                را               از                او
# 4                     ز                که              NaN                بر
# 5                    که                از              NaN                از
# 6                    را                او              NaN               NaN
# 7                    او           بود#است              NaN               NaN
# 8                    چو                آن              NaN               NaN
# 9                   این                 ز              NaN               NaN
# 10              بود#است               NaN              NaN               NaN
# 11                  است               NaN              NaN               NaN
# 12                  همی               NaN              NaN               NaN
# 13                   هر               NaN              NaN               NaN
# 14                  خرد               NaN              NaN               NaN
# 15                شد#شو               NaN              NaN               NaN
# 16                   آن               NaN              NaN               NaN
# 17                 جهان               NaN              NaN               NaN
# 18                  سخن               NaN              NaN               NaN
# 19                آمد#آ               NaN              NaN               NaN
#
#    chapter_5, جمشید chapter_6, ضحاک chapter_7, فریدون chapter_8, منوچهر  \
# 0                 و              به                 و                 و
# 1                به               و                به                به
# 2                از              که                از                از
# 3                 ز              از                 ز                که
# 4                را               ز                که                بر
# 5                چو              بر                را                 ز
# 6                بر              را                چو                را
# 7                او              آن                بر                چو
# 8            کرد#کن              چو               شاه             شد#شو
# 9                که         بود#است             شد#شو            گفت#گو
# 10               آن              او            کرد#کن                با
# 11          بود#است              تو            گفت#گو               یکی
# 12              بدو            ضحاک                آن                تو
# 13           گفت#گو             یکی               همه               سام
# 14              این           شد#شو                با             آمد#آ
# 15               هر          گفت#گو                سر               همی
# 16              یکی            اندر             آمد#آ                من
# 17            شد#شو           آمد#آ              اندر                او
# 18             جهان              سر                هر            کرد#کن
# 19             اندر             همی                دل           بود#است
#
#    chapter_9, پادشاهی نوذر chapter_10, پادشاهی زوطهماسپ  ...  \
# 0                       به                            و  ...
# 1                        و                            ز  ...
# 2                       که                           به  ...
# 3                        ز                          NaN  ...
# 4                       از                          NaN  ...
# 5                    شد#شو                          NaN  ...
# 6                       چو                          NaN  ...
# 7                       را                          NaN  ...
# 8                       بر                          NaN  ...
# 9                       با                          NaN  ...
# 10                   آمد#آ                          NaN  ...
# 11                     همی                          NaN  ...
# 12                  کرد#کن                          NaN  ...
# 13                      سر                          NaN  ...
# 14                  گفت#گو                          NaN  ...
# 15                     یکی                          NaN  ...
# 16                    اندر                          NaN  ...
# 17                     شاه                          NaN  ...
# 18                 بود#است                          NaN  ...
# 19                     روی                          NaN  ...
#
#    chapter_52, پادشاهی کسری نوشین روان چهل و هشت سال بود  \
# 0                                                   و
# 1                                                  که
# 2                                                  به
# 3                                                   ز
# 4                                                  از
# 5                                                  را
# 6                                                 شاه
# 7                                                  بر
# 8                                             بود#است
# 9                                                  با
# 10                                             گفت#گو
# 11                                              شد#شو
# 12                                                 چو
# 13                                                 او
# 14                                                همه
# 15                                             کرد#کن
# 16                                               چنین
# 17                                                داد
# 18                                                 دل
# 19                                                یکی
#
#    chapter_53, پادشاهی هرمزد دوازده سال بود chapter_54, پادشاهی خسرو پرویز  \
# 0                                        که                              و
# 1                                         و                             که
# 2                                        به                             به
# 3                                        را                              ز
# 4                                         ز                             از
# 5                                        از                             را
# 6                                       شاه                         گفت#گو
# 7                                    گفت#گو                             بر
# 8                                     شد#شو                          شد#شو
# 9                                        بر                             چو
# 10                                  بود#است                        بود#است
# 11                                       آن                             تو
# 12                                       تو                             آن
# 13                                       چو                         کرد#کن
# 14                                       با                             با
# 15                                   کرد#کن                            شاه
# 16                                    بهرام                             او
# 17                                       تا                            یکی
# 18                                    آمد#آ                             تا
# 19                                      یکی                          آمد#آ
#
#    chapter_55, پادشاهی شیرویه chapter_56, پادشاهی اردشیر شیروی  \
# 0                           و                                و
# 1                          به                               به
# 2                          که                               که
# 3                           ز                                ز
# 4                          از                            شد#شو
# 5                          را                              NaN
# 6                          تو                              NaN
# 7                          بر                              NaN
# 8                          چو                              NaN
# 9                          آن                              NaN
# 10                    بود#است                              NaN
# 11                     گفت#گو                              NaN
# 12                        همه                              NaN
# 13                         او                              NaN
# 14                         بد                              NaN
# 15                         من                              NaN
# 16                      شد#شو                              NaN
# 17                        شاه                              NaN
# 18                         در                              NaN
# 19                     کرد#کن                              NaN
#
#    chapter_57, پادشاهی فرایین chapter_58, پادشاهی پوران دخت  \
# 0                          به                            به
# 1                          از                           NaN
# 2                          که                           NaN
# 3                          را                           NaN
# 4                           و                           NaN
# 5                         NaN                           NaN
# 6                         NaN                           NaN
# 7                         NaN                           NaN
# 8                         NaN                           NaN
# 9                         NaN                           NaN
# 10                        NaN                           NaN
# 11                        NaN                           NaN
# 12                        NaN                           NaN
# 13                        NaN                           NaN
# 14                        NaN                           NaN
# 15                        NaN                           NaN
# 16                        NaN                           NaN
# 17                        NaN                           NaN
# 18                        NaN                           NaN
# 19                        NaN                           NaN
#
#    chapter_59, پادشاهی آزرم دخت chapter_60, پادشاهی فرخ زاد  \
# 0                           NaN                         NaN
# 1                           NaN                         NaN
# 2                           NaN                         NaN
# 3                           NaN                         NaN
# 4                           NaN                         NaN
# 5                           NaN                         NaN
# 6                           NaN                         NaN
# 7                           NaN                         NaN
# 8                           NaN                         NaN
# 9                           NaN                         NaN
# 10                          NaN                         NaN
# 11                          NaN                         NaN
# 12                          NaN                         NaN
# 13                          NaN                         NaN
# 14                          NaN                         NaN
# 15                          NaN                         NaN
# 16                          NaN                         NaN
# 17                          NaN                         NaN
# 18                          NaN                         NaN
# 19                          NaN                         NaN
#
#    chapter_61, پادشاهی یزدگرد
# 0                           و
# 1                          به
# 2                          که
# 3                           ز
# 4                          از
# 5                          بر
# 6                          را
# 7                       شد#شو
# 8                          چو
# 9                       آمد#آ
# 10                         تو
# 11                         با
# 12                        شاه
# 13                     گفت#گو
# 14                     کرد#کن
# 15                    بود#است
# 16                         نه
# 17                         او
# 18                        این
# 19                         آن
#
# [20 rows x 61 columns]

# %% [markdown]
# Here there is common stopwords in all chapters.

# %%
all_common = set(ferdowsi_stopwords_chapter_based[0])
for i in range(1, len(ferdowsi_stopwords_chapter_based)):
    if len(ferdowsi_stopwords_chapter_based[i]) <= 10:
        continue
    
    all_common &= set(ferdowsi_stopwords_chapter_based[i])
    
print(f'Number of stopwords in common: {len(all_common)}')
all_common
# Out:
# Number of stopwords in common: 8
# {'از', 'بر', 'به', 'ز', 'شد#شو', 'و', 'چو', 'که'}

# %% [markdown]
# ## Compare the stopwords

# %% [markdown]
# ### Khayyam and Ferdowsi All
#
# In the following cells, I compared the stopwords of Khayyam and Ferdowsi. I showed a dataframe, common stopwords, and common stopwords in the top 20.
#
# As we can see, there are many common stopwords and somehow, there are many many stopwords in Khayyam poems.

# %%
stopwords_dataframe = pd.DataFrame(khayyam_preprocessor.stopwords_count, columns=['khayyam stopwords', 'khayyam count'])
stopwords_dataframe[['ferdowsi stopwords', 'ferdowsi count']] = all_ferdowsi_preprocessor.stopwords_count[
                                                                :len(khayyam_preprocessor.stopwords_count)]
stopwords_dataframe.head(20)
# Out:
#    khayyam stopwords  khayyam count ferdowsi stopwords ferdowsi count
# 0                  و            230                  و          24138
# 1                 که            185                 به          17809
# 2                 به            122                 که          12569
# 3                 از             95                  ز          12017
# 4                 در             84                 از          10540
# 5                  ز             69                 بر           8330
# 6                 تو             55                 را           7676
# 7                است             54                 چو           6423
# 8                این             51              شد#شو           5475
# 9                 بر             51             گفت#گو           5471
# 10                من             50                 با           4663
# 11                را             48                شاه           4302
# 12             شد#شو             45            بود#است           4233
# 13                آن             36             کرد#کن           4174
# 14                چه             36                 تو           4072
# 15                تا             33                همی           3943
# 16                هر             32                 او           3812
# 17                چو             32              آمد#آ           3770
# 18               خاک             32                 آن           3656
# 19               چون             31                یکی           3389

# %%
# I choose 10, by sense. When I changed it to 30, Number of stopwords in Khayyam = Number of stopwords in common = 22!

khayyam_stop_words = [khayyam_preprocessor.stopwords for khayyam_preprocessor.stopwords, count in khayyam_preprocessor.stopwords_count if count > 10]
ferdowsi_stopwords = [current_stopwords for current_stopwords, count in all_ferdowsi_preprocessor.stopwords_count if count > 10]

# %%
common_stopwords = set(khayyam_stop_words) & set(ferdowsi_stopwords)
print(f'Number of stopwords in Khayyam: {len(khayyam_stop_words)}')
print(f'Number of stopwords in Ferdowsi: {len(ferdowsi_stopwords)}')
print(f'Number of stopwords in common: {len(common_stopwords)}')
print(f'Stopwords in common: {set(khayyam_stop_words) & set(ferdowsi_stopwords)}')
# Out:
# Number of stopwords in Khayyam: 70
# Number of stopwords in Ferdowsi: 3361
# Number of stopwords in common: 67
# Stopwords in common: {'فلک', 'دانست#دان', 'همه', 'نیست', 'داشت#دار', 'و', 'که', 'خوش', 'با', 'بر', 'کرد#کن', 'غم', 'ز', 'یک', 'جهان', 'شد#شو', '؟', 'خورد#خور', 'در', 'چرخ', 'گفت#گو', 'از', 'هر', 'دو', 'گل', 'خود', 'کس', 'یا', 'چه', 'چو', 'پیش', 'آمد#آ', 'آن', 'بهشت', 'مکن', 'سبزه', 'دست', 'این', 'بود#است', 'اگر', 'باده', 'چند', 'جام', 'صد', 'سر', 'است', 'را', 'نه', 'ما', 'دل', 'رفت#رو', 'باش', 'گدشت#گذر', 'گر', 'تا', 'به', 'چون', 'خاک', 'من', 'او', 'دید#بین', 'باشید#باش', 'دی', 'مرا', 'ای', 'زمین', 'تو'}

# %%
common_top_20_stopwords = set(khayyam_stop_words[:20]) & set(ferdowsi_stopwords[:20])
print(f'Number of stopwords in common in top 20: {len(common_top_20_stopwords)}')
print(f'Stopwords in common in top 20: {set(khayyam_stop_words[:20]) & set(ferdowsi_stopwords[:20])}')
# Out:
# Number of stopwords in common in top 20: 11
# Stopwords in common in top 20: {'آن', 'به', 'از', 'و', 'که', 'بر', 'را', 'چو', 'ز', 'شد#شو', 'تو'}

# %% [markdown]
# ### Ferdowsi Chapter Based and Ferdowsi All
#
# Here, I compared the stopwords of Ferdowsi chapter-based and all Ferdowsi in top 20 stopwords.
# The result is a dataframe that shows the common stopwords between each chapter and all Ferdowsi, number of them and their percentage.

# %%
print('Ferdowsi all stopwords:')
all_ferdowsi_stopwords_20 = all_ferdowsi_preprocessor.stopwords[:20]
all_ferdowsi_stopwords_20
# Out:
# Ferdowsi all stopwords:
# ['و',
#  'به',
#  'که',
#  'ز',
#  'از',
#  'بر',
#  'را',
#  'چو',
#  'شد#شو',
#  'گفت#گو',
#  'با',
#  'شاه',
#  'بود#است',
#  'کرد#کن',
#  'تو',
#  'همی',
#  'او',
#  'آمد#آ',
#  'آن',
#  'یکی']

# %%
print('Ferdowsi chapter based stopwords:')
dataframe_top_20
# Out:
# Ferdowsi chapter based stopwords:
#    chapter_1, آغاز کتاب chapter_2, کیومرث chapter_3, هوشنگ chapter_4, طهمورث  \
# 0                     و                 و                و                به
# 1                    به                به           کرد#کن                 و
# 2                    از                بر               به                را
# 3                    بر                را               از                او
# 4                     ز                که              NaN                بر
# 5                    که                از              NaN                از
# 6                    را                او              NaN               NaN
# 7                    او           بود#است              NaN               NaN
# 8                    چو                آن              NaN               NaN
# 9                   این                 ز              NaN               NaN
# 10              بود#است               NaN              NaN               NaN
# 11                  است               NaN              NaN               NaN
# 12                  همی               NaN              NaN               NaN
# 13                   هر               NaN              NaN               NaN
# 14                  خرد               NaN              NaN               NaN
# 15                شد#شو               NaN              NaN               NaN
# 16                   آن               NaN              NaN               NaN
# 17                 جهان               NaN              NaN               NaN
# 18                  سخن               NaN              NaN               NaN
# 19                آمد#آ               NaN              NaN               NaN
#
#    chapter_5, جمشید chapter_6, ضحاک chapter_7, فریدون chapter_8, منوچهر  \
# 0                 و              به                 و                 و
# 1                به               و                به                به
# 2                از              که                از                از
# 3                 ز              از                 ز                که
# 4                را               ز                که                بر
# 5                چو              بر                را                 ز
# 6                بر              را                چو                را
# 7                او              آن                بر                چو
# 8            کرد#کن              چو               شاه             شد#شو
# 9                که         بود#است             شد#شو            گفت#گو
# 10               آن              او            کرد#کن                با
# 11          بود#است              تو            گفت#گو               یکی
# 12              بدو            ضحاک                آن                تو
# 13           گفت#گو             یکی               همه               سام
# 14              این           شد#شو                با             آمد#آ
# 15               هر          گفت#گو                سر               همی
# 16              یکی            اندر             آمد#آ                من
# 17            شد#شو           آمد#آ              اندر                او
# 18             جهان              سر                هر            کرد#کن
# 19             اندر             همی                دل           بود#است
#
#    chapter_9, پادشاهی نوذر chapter_10, پادشاهی زوطهماسپ  ...  \
# 0                       به                            و  ...
# 1                        و                            ز  ...
# 2                       که                           به  ...
# 3                        ز                          NaN  ...
# 4                       از                          NaN  ...
# 5                    شد#شو                          NaN  ...
# 6                       چو                          NaN  ...
# 7                       را                          NaN  ...
# 8                       بر                          NaN  ...
# 9                       با                          NaN  ...
# 10                   آمد#آ                          NaN  ...
# 11                     همی                          NaN  ...
# 12                  کرد#کن                          NaN  ...
# 13                      سر                          NaN  ...
# 14                  گفت#گو                          NaN  ...
# 15                     یکی                          NaN  ...
# 16                    اندر                          NaN  ...
# 17                     شاه                          NaN  ...
# 18                 بود#است                          NaN  ...
# 19                     روی                          NaN  ...
#
#    chapter_52, پادشاهی کسری نوشین روان چهل و هشت سال بود  \
# 0                                                   و
# 1                                                  که
# 2                                                  به
# 3                                                   ز
# 4                                                  از
# 5                                                  را
# 6                                                 شاه
# 7                                                  بر
# 8                                             بود#است
# 9                                                  با
# 10                                             گفت#گو
# 11                                              شد#شو
# 12                                                 چو
# 13                                                 او
# 14                                                همه
# 15                                             کرد#کن
# 16                                               چنین
# 17                                                داد
# 18                                                 دل
# 19                                                یکی
#
#    chapter_53, پادشاهی هرمزد دوازده سال بود chapter_54, پادشاهی خسرو پرویز  \
# 0                                        که                              و
# 1                                         و                             که
# 2                                        به                             به
# 3                                        را                              ز
# 4                                         ز                             از
# 5                                        از                             را
# 6                                       شاه                         گفت#گو
# 7                                    گفت#گو                             بر
# 8                                     شد#شو                          شد#شو
# 9                                        بر                             چو
# 10                                  بود#است                        بود#است
# 11                                       آن                             تو
# 12                                       تو                             آن
# 13                                       چو                         کرد#کن
# 14                                       با                             با
# 15                                   کرد#کن                            شاه
# 16                                    بهرام                             او
# 17                                       تا                            یکی
# 18                                    آمد#آ                             تا
# 19                                      یکی                          آمد#آ
#
#    chapter_55, پادشاهی شیرویه chapter_56, پادشاهی اردشیر شیروی  \
# 0                           و                                و
# 1                          به                               به
# 2                          که                               که
# 3                           ز                                ز
# 4                          از                            شد#شو
# 5                          را                              NaN
# 6                          تو                              NaN
# 7                          بر                              NaN
# 8                          چو                              NaN
# 9                          آن                              NaN
# 10                    بود#است                              NaN
# 11                     گفت#گو                              NaN
# 12                        همه                              NaN
# 13                         او                              NaN
# 14                         بد                              NaN
# 15                         من                              NaN
# 16                      شد#شو                              NaN
# 17                        شاه                              NaN
# 18                         در                              NaN
# 19                     کرد#کن                              NaN
#
#    chapter_57, پادشاهی فرایین chapter_58, پادشاهی پوران دخت  \
# 0                          به                            به
# 1                          از                           NaN
# 2                          که                           NaN
# 3                          را                           NaN
# 4                           و                           NaN
# 5                         NaN                           NaN
# 6                         NaN                           NaN
# 7                         NaN                           NaN
# 8                         NaN                           NaN
# 9                         NaN                           NaN
# 10                        NaN                           NaN
# 11                        NaN                           NaN
# 12                        NaN                           NaN
# 13                        NaN                           NaN
# 14                        NaN                           NaN
# 15                        NaN                           NaN
# 16                        NaN                           NaN
# 17                        NaN                           NaN
# 18                        NaN                           NaN
# 19                        NaN                           NaN
#
#    chapter_59, پادشاهی آزرم دخت chapter_60, پادشاهی فرخ زاد  \
# 0                           NaN                         NaN
# 1                           NaN                         NaN
# 2                           NaN                         NaN
# 3                           NaN                         NaN
# 4                           NaN                         NaN
# 5                           NaN                         NaN
# 6                           NaN                         NaN
# 7                           NaN                         NaN
# 8                           NaN                         NaN
# 9                           NaN                         NaN
# 10                          NaN                         NaN
# 11                          NaN                         NaN
# 12                          NaN                         NaN
# 13                          NaN                         NaN
# 14                          NaN                         NaN
# 15                          NaN                         NaN
# 16                          NaN                         NaN
# 17                          NaN                         NaN
# 18                          NaN                         NaN
# 19                          NaN                         NaN
#
#    chapter_61, پادشاهی یزدگرد
# 0                           و
# 1                          به
# 2                          که
# 3                           ز
# 4                          از
# 5                          بر
# 6                          را
# 7                       شد#شو
# 8                          چو
# 9                       آمد#آ
# 10                         تو
# 11                         با
# 12                        شاه
# 13                     گفت#گو
# 14                     کرد#کن
# 15                    بود#است
# 16                         نه
# 17                         او
# 18                        این
# 19                         آن
#
# [20 rows x 61 columns]

# %%
in_common_dataframe = pd.DataFrame()
number_of_in_common = []
for i in range(len(ferdowsi_stopwords_chapter_based)):
    in_common_series = pd.Series(list(set(dataframe_top_20.iloc[:, i]) & set(all_ferdowsi_preprocessor.stopwords)))
    in_common_dataframe[f'chapter_{i + 1}, {ferdowsi.chapters[i]}'] = in_common_series
    number_of_in_common.append(len(in_common_series))
    

first_row = []
for i in range(len(ferdowsi_stopwords_chapter_based)):
    first_row.append(f'{number_of_in_common[i]} -> {number_of_in_common[i] / len(all_ferdowsi_stopwords_20) * 100}%')
in_common_dataframe.loc[-1] = first_row
in_common_dataframe.index = in_common_dataframe.index + 1
in_common_dataframe.sort_index(inplace=True)
in_common_dataframe.rename(index={-1: 'Number of stopwords in common'}, inplace=True)
in_common_dataframe
# Out:
#    chapter_1, آغاز کتاب chapter_2, کیومرث chapter_3, هوشنگ chapter_4, طهمورث  \
# 0          20 -> 100.0%       10 -> 50.0%       4 -> 20.0%        6 -> 30.0%
# 1                     و                او               به                او
# 2                    که                به               از                به
# 3                    بر                از           کرد#کن                از
# 4                     ز           بود#است                و                 و
# 5                  جهان                 و              NaN                بر
# 6                   همی                که              NaN                را
# 7                 شد#شو                بر              NaN               NaN
# 8                    از                را              NaN               NaN
# 9                    هر                 ز              NaN               NaN
# 10                  سخن                آن              NaN               NaN
# 11                   چو               NaN              NaN               NaN
# 12                آمد#آ               NaN              NaN               NaN
# 13                   آن               NaN              NaN               NaN
# 14                  این               NaN              NaN               NaN
# 15              بود#است               NaN              NaN               NaN
# 16                  است               NaN              NaN               NaN
# 17                   را               NaN              NaN               NaN
# 18                  خرد               NaN              NaN               NaN
# 19                   او               NaN              NaN               NaN
# 20                   به               NaN              NaN               NaN
#
#    chapter_5, جمشید chapter_6, ضحاک chapter_7, فریدون chapter_8, منوچهر  \
# 0      20 -> 100.0%    20 -> 100.0%      20 -> 100.0%      20 -> 100.0%
# 1                 و               و               همه                 و
# 2                که              که                 و                که
# 3                بر              بر                که                با
# 4            کرد#کن               ز                با                بر
# 5                 ز             همی                بر            کرد#کن
# 6              جهان           شد#شو            کرد#کن                 ز
# 7             شد#شو          گفت#گو                 ز               همی
# 8            گفت#گو              از             شد#شو             شد#شو
# 9                از              چو            گفت#گو            گفت#گو
# 10               هر           آمد#آ                از                از
# 11               چو              آن                هر                چو
# 12               آن         بود#است                چو             آمد#آ
# 13              این              سر             آمد#آ           بود#است
# 14          بود#است              را                آن                را
# 15               را             یکی                سر               یکی
# 16              یکی            اندر                را               سام
# 17               او              او                دل                او
# 18               به              به              اندر                به
# 19              بدو            ضحاک                به                من
# 20             اندر              تو               شاه                تو
#
#    chapter_9, پادشاهی نوذر chapter_10, پادشاهی زوطهماسپ  ...  \
# 0             20 -> 100.0%                   3 -> 15.0%  ...
# 1                      روی                           به  ...
# 2                        و                            و  ...
# 3                       که                            ز  ...
# 4                       با                          NaN  ...
# 5                       بر                          NaN  ...
# 6                   کرد#کن                          NaN  ...
# 7                        ز                          NaN  ...
# 8                      همی                          NaN  ...
# 9                    شد#شو                          NaN  ...
# 10                  گفت#گو                          NaN  ...
# 11                      از                          NaN  ...
# 12                      چو                          NaN  ...
# 13                   آمد#آ                          NaN  ...
# 14                 بود#است                          NaN  ...
# 15                      سر                          NaN  ...
# 16                      را                          NaN  ...
# 17                     یکی                          NaN  ...
# 18                    اندر                          NaN  ...
# 19                      به                          NaN  ...
# 20                     شاه                          NaN  ...
#
#    chapter_52, پادشاهی کسری نوشین روان چهل و هشت سال بود  \
# 0                                        20 -> 100.0%
# 1                                                 همه
# 2                                                 داد
# 3                                                   و
# 4                                                  که
# 5                                                  با
# 6                                                  بر
# 7                                                چنین
# 8                                              کرد#کن
# 9                                                   ز
# 10                                              شد#شو
# 11                                             گفت#گو
# 12                                                 از
# 13                                                 چو
# 14                                            بود#است
# 15                                                 را
# 16                                                 دل
# 17                                                یکی
# 18                                                 او
# 19                                                 به
# 20                                                شاه
#
#    chapter_53, پادشاهی هرمزد دوازده سال بود chapter_54, پادشاهی خسرو پرویز  \
# 0                              20 -> 100.0%                   20 -> 100.0%
# 1                                         و                              و
# 2                                        که                             که
# 3                                        با                             با
# 4                                        بر                             بر
# 5                                    کرد#کن                         کرد#کن
# 6                                         ز                              ز
# 7                                     شد#شو                          شد#شو
# 8                                    گفت#گو                         گفت#گو
# 9                                        از                             از
# 10                                    بهرام                             چو
# 11                                       چو                          آمد#آ
# 12                                    آمد#آ                             آن
# 13                                       آن                        بود#است
# 14                                  بود#است                             را
# 15                                       را                            یکی
# 16                                      یکی                             او
# 17                                       تا                             به
# 18                                       به                             تا
# 19                                      شاه                            شاه
# 20                                       تو                             تو
#
#    chapter_55, پادشاهی شیرویه chapter_56, پادشاهی اردشیر شیروی  \
# 0                20 -> 100.0%                       5 -> 25.0%
# 1                         همه                               به
# 2                           و                                و
# 3                          که                               که
# 4                          بر                                ز
# 5                      کرد#کن                            شد#شو
# 6                           ز                              NaN
# 7                       شد#شو                              NaN
# 8                          در                              NaN
# 9                          بد                              NaN
# 10                     گفت#گو                              NaN
# 11                         از                              NaN
# 12                         چو                              NaN
# 13                         آن                              NaN
# 14                    بود#است                              NaN
# 15                         را                              NaN
# 16                         او                              NaN
# 17                         به                              NaN
# 18                         من                              NaN
# 19                        شاه                              NaN
# 20                         تو                              NaN
#
#    chapter_57, پادشاهی فرایین chapter_58, پادشاهی پوران دخت  \
# 0                  5 -> 25.0%                     1 -> 5.0%
# 1                          به                            به
# 2                          از                           NaN
# 3                           و                           NaN
# 4                          که                           NaN
# 5                          را                           NaN
# 6                         NaN                           NaN
# 7                         NaN                           NaN
# 8                         NaN                           NaN
# 9                         NaN                           NaN
# 10                        NaN                           NaN
# 11                        NaN                           NaN
# 12                        NaN                           NaN
# 13                        NaN                           NaN
# 14                        NaN                           NaN
# 15                        NaN                           NaN
# 16                        NaN                           NaN
# 17                        NaN                           NaN
# 18                        NaN                           NaN
# 19                        NaN                           NaN
# 20                        NaN                           NaN
#
#    chapter_59, پادشاهی آزرم دخت chapter_60, پادشاهی فرخ زاد  \
# 0                     0 -> 0.0%                   0 -> 0.0%
# 1                           NaN                         NaN
# 2                           NaN                         NaN
# 3                           NaN                         NaN
# 4                           NaN                         NaN
# 5                           NaN                         NaN
# 6                           NaN                         NaN
# 7                           NaN                         NaN
# 8                           NaN                         NaN
# 9                           NaN                         NaN
# 10                          NaN                         NaN
# 11                          NaN                         NaN
# 12                          NaN                         NaN
# 13                          NaN                         NaN
# 14                          NaN                         NaN
# 15                          NaN                         NaN
# 16                          NaN                         NaN
# 17                          NaN                         NaN
# 18                          NaN                         NaN
# 19                          NaN                         NaN
# 20                          NaN                         NaN
#
#    chapter_61, پادشاهی یزدگرد
# 0                20 -> 100.0%
# 1                           و
# 2                          که
# 3                          با
# 4                          بر
# 5                      کرد#کن
# 6                           ز
# 7                       شد#شو
# 8                      گفت#گو
# 9                          از
# 10                         چو
# 11                      آمد#آ
# 12                         آن
# 13                        این
# 14                    بود#است
# 15                         را
# 16                         نه
# 17                         او
# 18                         به
# 19                        شاه
# 20                         تو
#
# [21 rows x 61 columns]

# %% [markdown]
# # Task 1: Keyword Extraction

# %%
# !pip install yake
# Out:
# Requirement already satisfied: yake in /Users/AMF/opt/anaconda3/lib/python3.8/site-packages (0.4.8)
# Requirement already satisfied: tabulate in /Users/AMF/opt/anaconda3/lib/python3.8/site-packages (from yake) (0.9.0)
# Requirement already satisfied: click>=6.0 in /Users/AMF/opt/anaconda3/lib/python3.8/site-packages (from yake) (8.1.3)
# Requirement already satisfied: numpy in /Users/AMF/opt/anaconda3/lib/python3.8/site-packages (from yake) (1.24.3)
# Requirement already satisfied: segtok in /Users/AMF/opt/anaconda3/lib/python3.8/site-packages (from yake) (1.5.11)
# Requirement already satisfied: networkx in /Users/AMF/opt/anaconda3/lib/python3.8/site-packages (from yake) (3.1)
# Requirement already satisfied: jellyfish in /Users/AMF/opt/anaconda3/lib/python3.8/site-packages (from yake) (1.0.3)
# Requirement already satisfied: regex in /Users/AMF/opt/anaconda3/lib/python3.8/site-packages (from segtok->yake) (2023.10.3)

# %%
import yake

# %%
class KeywordExtractor:
    def __init__(self, n=3, top=20):
        self.yake_extractor = yake.KeywordExtractor(lan='fa', n=n, top=top)

    def extract_keywords(self, chapter: list):
        return self.yake_extractor.extract_keywords(' '.join([' '.join(stanza) for stanza in chapter]))


def run_keyword_extraction(poem, poem_no_stopwords):
    """
    It runs the keyword extraction on the poem and poem_no_stopwords. It returns a dataframe of keywords and their scores both for the poem and poem_no_stopwords.
    """
    
    keyword_extractor = KeywordExtractor()
    keywords = keyword_extractor.extract_keywords(poem)
    keywords_no_stopwords = keyword_extractor.extract_keywords(poem_no_stopwords)

    dataframe = pd.DataFrame(keywords, columns=['keywords', 'score'])
    dataframe[['keywords_no_stopwords', 'score_no_stopwords']] = keywords_no_stopwords
    return dataframe

# %%
khayyam_preprocessed = khayyam_dataframe['preprocessed']
khayyam_preprocessed_no_stopwords = khayyam_dataframe['preprocessed_no_stopwords']
khayyam_keyword_dataframe = run_keyword_extraction(khayyam_preprocessed, khayyam_preprocessed_no_stopwords)

# %% [markdown]
# ## Keywords of Khayyam
#
# In the following cell, you can see the top 20 keywords of Khayyam. I also print the stopwords to see their effect on the keywords.
#
# As we can see, the keywords are different in the preprocessed and preprocessed_no_stopwords columns because of removing stopwords and also their score, change.
# Scores get higher when we remove the stopwords.

# %%
print(khayyam_preprocessor.stopwords[:10])
khayyam_keyword_dataframe
# Out:
# تیرمه
#                  keywords     score keywords_no_stopwords score_no_stopwords
# 0           آمد#آ خوش باش  0.000009     خوش باش دانست#دان           0.000053
# 1       خوش باش دانست#دان  0.000010         آمد#آ خوش باش           0.000059
# 2    دانست#دان گفت#گو این  0.000013           خوش باش عمر            0.00012
# 3            خوش نیست خوش  0.000014          نیست خوش باش           0.000121
# 4         گفت#گو این کوزه  0.000015           خوش باش دمی           0.000135
# 5            نیست خوش باش  0.000018          خوش نیست خوش           0.000136
# 6        بوده‌ست این کوزه  0.000020      یافت#یاب خوش باش           0.000139
# 7          کرد#کن این عقل  0.000020          مستی خوش باش           0.000139
# 8         بود#است این عقل  0.000020         خوش باش کارگه           0.000139
# 9             این چرخ فلک  0.000020          باده لعل باش            0.00014
# 10       گفت#گوی خوش نیست  0.000023           باش عمر باد           0.000143
# 11     کوزه‌گر کوزه شد#شو  0.000024       رست#روی خوش باش           0.000143
# 12    بود#است اکنون شد#شو  0.000025          پدید خوش باش           0.000149
# 13            خاک این بحر  0.000025       شست#شوی خوش باش           0.000149
# 14          اندر این عالم  0.000025          حالی خوش باش           0.000151
# 15       بود#است زهره این  0.000026         سرمست خوش باش           0.000157
# 16   بود#است گفت#گوی بهشت  0.000028        خوش باش پخت#پز           0.000157
# 17  خوش باشید#باش گفت#گوی  0.000029      گفت#گوی خوش نیست           0.000161
# 18     خاک فروخواهی شد#شو  0.000029     باش کارگه کوزه‌گر           0.000163
# 19         خاک شد#شو دودی  0.000029           وقت سحر خیز           0.000164

# %% [markdown]
# ## Keywords of Ferdowsi (All)
#
# In the following cell, you can see the top 20 keywords of Ferdowsi. I also print the stopwords to see their effect on the keywords.
#
# As we can see, the keywords are different in the preprocessed and preprocessed_no_stopwords columns because of removing stopwords and also their score, change.
# Here, because of the length of the document, the scores are much lower than the Khayyam, and after removing the stopwords, the scores get wore, so maybe here we need to change the number of stopwords (increase 10 to 20 or 30).

# %%
all_ferdowsi_preprocessed = all_ferdowsi_dataframe['preprocessed']
all_ferdowsi_preprocessed_no_stopwords = all_ferdowsi_dataframe['preprocessed_no_stopwords']
all_ferdowsi_keyword_dataframe = run_keyword_extraction(all_ferdowsi_preprocessed,
                                                        all_ferdowsi_preprocessed_no_stopwords)

# %%
print(all_ferdowsi_preprocessor.stopwords[:10])
all_ferdowsi_keyword_dataframe
# Out:
# ['و', 'به', 'که', 'ز', 'از', 'بر', 'را', 'چو', 'شد#شو', 'گفت#گو']
#               keywords         score keywords_no_stopwords score_no_stopwords
# 0       بدو گفت#گو شاه  1.544084e-09       سپاه اندر آمد#آ                0.0
# 1      چنین گفت#گو کای  2.177486e-09       اندر آمد#آ سپاه                0.0
# 2      چنین گفت#گو شاه  2.578779e-09        اندر آمد#آ جای                0.0
# 3       بدو گفت#گو کای  3.112367e-09        اندر آمد#آ یکی                0.0
# 4      سپاه اندر آمد#آ  3.917133e-09        اندر آمد#آ همی                0.0
# 5     شد#شو بدو گفت#گو  4.350110e-09        جنگ اندر آمد#آ                0.0
# 6       گفت#گو کای شاه  4.628183e-09       آمد#آ نزدیک شاه                0.0
# 7    کرد#کن بدو گفت#گو  4.718772e-09      برو آفرین کرد#کن                0.0
# 8   کرد#کن چنین گفت#گو  4.816064e-09        خاک اندر آمد#آ                0.0
# 9       شاه بدو گفت#گو  4.941068e-09           بدو شاه این                0.0
# 10  بود#است بدو گفت#گو  5.620941e-09           شاه این سخن                0.0
# 11      گفت#گو شاه این  5.758267e-09       شاه همی بود#است                0.0
# 12    بدو گفت#گو بهرام  6.215084e-09        اندر آمد#آ جنگ                0.0
# 13     شاه چنین گفت#گو  6.347762e-09        شاه اندر آمد#آ                0.0
# 14   شد#شو چنین گفت#گو  6.901880e-09      شاه کرد#کن آفرین                0.0
# 15     شاه جهان گفت#گو  7.891688e-09     اندر آورد#آور پای                0.0
# 16     گفت#گو شاه جهان  7.891688e-09           بدو کای شاه                0.0
# 17     بدو گفت#گو رستم  8.324634e-09        کوه اندر آمد#آ                0.0
# 18      گفت#گو این سخن  8.818522e-09        اندر آمد#آ گرد                0.0
# 19      همی گفت#گو کای  9.037424e-09        باد اندر آمد#آ                0.0

# %% [markdown]
# # Task 2: Convert the Poems to Clear Sentence
#
# I run this just on Khayyam to see its performance. It doesn't seem so good, just not bad :). I just sort them based on a common tag occurrences in a persian sentences. I may use som better heuristics in the future!

# %%
# !mkdir resources
# !wget -O resources/pos_tagger.model https://drive.usercontent.google.com/download\?id\=1Q3JK4NVUC2t5QT63aDiVrCRBV225E_B3\&export\=download\&authuser\=0
# Out:
# --2024-04-02 07:15:03--  https://drive.usercontent.google.com/download?id=1Q3JK4NVUC2t5QT63aDiVrCRBV225E_B3&export=download&authuser=0
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 198.18.0.182
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|198.18.0.182|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 19246648 (18M) [application/octet-stream]
# Saving to: ‘resources/pos_tagger.model’
#
# resources/pos_tagge 100%[===================>]  18.35M   826KB/s    in 20s
#
# 2024-04-02 07:15:26 (925 KB/s) - ‘resources/pos_tagger.model’ saved [19246648/19246648]

# %% [markdown]
# First, let's find all tags in Khayyam poems.
# I don't use the preprocessed texts because I want to convert the original poem to a sentence.

# %%
tagger = POSTagger(model='resources/pos_tagger.model')

# %%
all_tags = set()

for stanza in khayyam_dataframe['original']:
    current_pos_tagger = tagger.tag(word_tokenize(stanza))
    all_tags = all_tags.union(set([tag for _, tag in current_pos_tagger]))
    
all_tags
# Out:
# {'ADJ',
#  'ADJ,EZ',
#  'ADP',
#  'ADP,EZ',
#  'ADV',
#  'ADV,EZ',
#  'CCONJ',
#  'DET',
#  'DET,EZ',
#  'INTJ',
#  'NOUN',
#  'NOUN,EZ',
#  'NUM',
#  'NUM,EZ',
#  'PRON',
#  'PUNCT',
#  'SCONJ',
#  'VERB'}

# %% [markdown]
# Now, we use the output and sort it based on common tag occurences in a persian sentence.

# %%
tag_order = [
    'NOUN',
    'NOUN,EZ',
    'ADJ',
    'ADJ,EZ',
    'ADV',
    'ADV,EZ',
    'PRON',
    'DET',
    'DET,EZ',
    'NUM',
    'NUM,EZ',
    'VERB',
    'ADP',
    'ADP,EZ',
    'CCONJ',
    'SCONJ',
    'INTJ',
    'PUNCT'
]

def run_pos_tagger(poem):
    tagged = tagger.tag(word_tokenize(poem))
    
    # I removed some tags because I think they are not useful for this task and they need some better heuristics.
    tagged_clean = [(word, tag) for word, tag in tagged if tag != 'ADP' and tag != 'ADP,EZ' and
                    tag != 'CCONJ' and tag != 'SCONJ' and tag != 'INTJ' and tag != 'PUNCT']
    dataframe = pd.DataFrame(tagged_clean, columns=['word', 'tag'])
    dataframe['ordered sentence'] = dataframe['tag'].apply(lambda x: tag_order.index(x))
    dataframe = dataframe.sort_values(by='ordered sentence')
    return dataframe

# %% [markdown]
# The indexes are the true order of the poem. The visualized order is the order of the tags in the tag_order list.

# %%
run_pos_tagger(khayyam_dataframe['original'][0])
# Out:
#     word      tag  ordered sentence
# 3     دل  NOUN,EZ                 1
# 1    بتا      ADV                 4
# 4     ما     PRON                 6
# 0  برخیز     VERB                11
# 2    بیا     VERB                11

# %%
for stanza in khayyam_dataframe['original']:
    print(run_pos_tagger(stanza))
# Out:
#     word      tag  ordered sentence
# 3     دل  NOUN,EZ                 1
# 1    بتا      ADV                 4
# 4     ما     PRON                 6
# 0  برخیز     VERB                11
# 2    بیا     VERB                11
#      word      tag  ordered sentence
# 1      کن     NOUN                 0
# 0      حل  NOUN,EZ                 1
# 2    جمال  NOUN,EZ                 1
# 4    مشکل  NOUN,EZ                 1
# 3  خویشتن     PRON                 6
# 5      ما     PRON                 6
#    word      tag  ordered sentence
# 2  شراب     NOUN                 0
# 1  کوزه  NOUN,EZ                 1
# 4   نوش      ADJ                 2
# 3    هم     PRON                 6
# 0    یک      NUM                 9
# 5  کنیم     VERB                11
#       word      tag  ordered sentence
# 0      زآن     NOUN                 0
# 2  کوزه‌ها     NOUN                 0
# 4       گل  NOUN,EZ                 1
# 1      پیش      ADV                 4
# 5       ما     PRON                 6
# 3     کنند     VERB                11
#       word   tag  ordered sentence
# 0     عهده  NOUN                 0
# 2      کسی  NOUN                 0
# 3     فردا   ADV                 4
# 1  نمی‌شود  VERB                11
#    word   tag  ordered sentence
# 0  حالی  NOUN                 0
# 4    دل  NOUN                 0
# 6  سودا  NOUN                 0
# 1   خوش   ADJ                 2
# 5    پر   ADJ                 2
# 3   این   DET                 7
# 2   دار  VERB                11
#      word      tag  ordered sentence
# 2  ماهتاب     NOUN                 0
# 3     ماه     NOUN                 0
# 4     ماه     NOUN                 0
# 0      می  NOUN,EZ                 1
# 1     نوش      ADJ                 2
#     word   tag  ordered sentence
# 0  بسیار   ADV                 4
# 3     ما  PRON                 6
# 1  بتابد  VERB                11
# 2  نیابد  VERB                11
#      word      tag  ordered sentence
# 0    قرآن     NOUN                 0
# 2    کلام     NOUN                 0
# 1    مهین  NOUN,EZ                 1
# 4      آن     PRON                 6
# 3  خوانند     VERB                11
#      word   tag  ordered sentence
# 2    دوام  NOUN                 0
# 0   گهگاه   ADV                 4
# 1      نه   ADV                 4
# 4      آن  PRON                 6
# 3  خوانند  VERB                11
#     word      tag  ordered sentence
# 2   آیتی     NOUN                 0
# 0    گرد  NOUN,EZ                 1
# 1  پیاله  NOUN,EZ                 1
# 4   مقیم      ADJ                 2
# 3    هست     VERB                11
#      word   tag  ordered sentence
# 1      جا  NOUN                 0
# 2    مدام   ADV                 4
# 4      آن  PRON                 6
# 0     همه   DET                 7
# 3  خوانند  VERB                11
#     word   tag  ordered sentence
# 0     می  NOUN                 0
# 2   طعنه  NOUN                 0
# 4  مستان  NOUN                 0
# 1  نخوری  VERB                11
# 3    مزن  VERB                11
#     word   tag  ordered sentence
# 0  بنیاد  NOUN                 0
# 3   حیله  NOUN                 0
# 4  دستان  NOUN                 0
# 2     تو  PRON                 6
# 1    مکن  VERB                11
#        word   tag  ordered sentence
# 4        می  NOUN                 0
# 1       غره   ADJ                 2
# 0        تو  PRON                 6
# 2      بدان  PRON                 6
# 3       مشو  VERB                11
# 5  می‌نخوری  VERB                11
#    word   tag  ordered sentence
# 1  لقمه  NOUN                 0
# 3    می  NOUN                 0
# 4  غلام  NOUN                 0
# 6    آن  PRON                 6
# 0    صد   NUM                 9
# 2  خوری  VERB                11
# 5   است  VERB                11
#      word      tag  ordered sentence
# 2     رنگ     NOUN                 0
# 3     بوی  NOUN,EZ                 1
# 5     مرا     PRON                 6
# 0      هر      DET                 7
# 1     چند      DET                 7
# 4  زیباست     VERB                11
#      word   tag  ordered sentence
# 0    لاله  NOUN                 0
# 1      رخ  NOUN                 0
# 2     سرو  NOUN                 0
# 4     مرا  PRON                 6
# 3  بالاست  VERB                11
#       word      tag  ordered sentence
# 3      خاک     NOUN                 0
# 2  طربخانۀ  NOUN,EZ                 1
# 0    معلوم      ADJ                 2
# 1      نشد     VERB                11
#     word      tag  ordered sentence
# 0   نقاش  NOUN,EZ                 1
# 1    ازل      ADJ                 2
# 4    مرا     PRON                 6
# 2     چه      DET                 7
# 3  آراست     VERB                11
#     word      tag  ordered sentence
# 1     می     NOUN                 0
# 2   مطرب     NOUN                 0
# 4    کنج  NOUN,EZ                 1
# 5   خراب      ADJ                 2
# 3    این      DET                 7
# 0  ماییم     VERB                11
#    word      tag  ordered sentence
# 0   جان     NOUN                 0
# 1    دل     NOUN                 0
# 2   جام     NOUN                 0
# 6  شراب     NOUN                 0
# 3  جامه  NOUN,EZ                 1
# 5   درد  NOUN,EZ                 1
# 4    پر   ADJ,EZ                 3
#    word      tag  ordered sentence
# 2  رحمت     NOUN                 0
# 4  عذاب     NOUN                 0
# 1  امید  NOUN,EZ                 1
# 3   بیم  NOUN,EZ                 1
# 0  فارغ      ADJ                 2
#    word   tag  ordered sentence
# 0  آزاد  NOUN                 0
# 1   خاک  NOUN                 0
# 2   باد  NOUN                 0
# 3   آتش  NOUN                 0
# 4    آب  NOUN                 0
#     word   tag  ordered sentence
# 1    قصر  NOUN                 0
# 2  جمشید  NOUN                 0
# 4    جام  NOUN                 0
# 3     او  PRON                 6
# 0     آن   DET                 7
# 5   گرفت  VERB                11
#    word   tag  ordered sentence
# 0   آهو  NOUN                 0
# 1   بچه  NOUN                 0
# 3  روبه  NOUN                 0
# 4  آرام   ADJ                 2
# 2   کرد  VERB                11
# 5  گرفت  VERB                11
#        word     tag  ordered sentence
# 0     بهرام    NOUN                 0
# 1       گور    NOUN                 0
# 4       عمر    NOUN                 0
# 3       همه  DET,EZ                 8
# 2  می‌گرفتی    VERB                11
#     word   tag  ordered sentence
# 2    گور  NOUN                 0
# 3  بهرام  NOUN                 0
# 1  چگونه   ADV                 4
# 0   دیدی  VERB                11
# 4   گرفت  VERB                11
#     word      tag  ordered sentence
# 0    ابر     NOUN                 0
# 4   سبزه     NOUN                 0
# 3     سر  NOUN,EZ                 1
# 2    باز      ADV                 4
# 1    آمد     VERB                11
# 5  گریست     VERB                11
#        word   tag  ordered sentence
# 0     بادهٔ  NOUN                 0
# 1     گلرنگ  NOUN                 0
# 3      زیست  NOUN                 0
# 2  نمی‌باید  VERB                11
#       word      tag  ordered sentence
# 1     سبزه     NOUN                 0
# 4     ماست     NOUN                 0
# 3  تماشاگه  NOUN,EZ                 1
# 2    امروز      ADV                 4
# 0      این      DET                 7
#       word      tag  ordered sentence
# 3  تماشاگه     NOUN                 0
# 0    سبزهٔ  NOUN,EZ                 1
# 1      خاک  NOUN,EZ                 1
# 2       ما     PRON                 6
# 4     کیست     VERB                11
#      word      tag  ordered sentence
# 2  سعادتت     NOUN                 0
# 1      گل  NOUN,EZ                 1
# 3   پربار      ADJ                 2
# 0   اکنون      ADV                 4
# 4     است     VERB                11
#     word      tag  ordered sentence
# 3     می     NOUN                 0
# 0    دست  NOUN,EZ                 1
# 2    جام  NOUN,EZ                 1
# 5  بیکار      ADJ                 2
# 4    چرا      ADV                 4
# 1     تو     PRON                 6
# 6    است     VERB                11
#     word      tag  ordered sentence
# 0     می     NOUN                 0
# 2  زمانه     NOUN                 0
# 3  دشمنی  NOUN,EZ                 1
# 4   غدار      ADJ                 2
# 1    خور     VERB                11
# 5    است     VERB                11
#       word      tag  ordered sentence
# 1      روز     NOUN                 0
# 0  دریافتن  NOUN,EZ                 1
# 3    دشوار      ADJ                 2
# 2     چنین     PRON                 6
# 4      است     VERB                11
#     word      tag  ordered sentence
# 2  دسترس  NOUN,EZ                 1
# 0  امروز      ADV                 4
# 3   فردا      ADV                 4
# 1     تو     PRON                 6
# 4   نیست     VERB                11
#        word   tag  ordered sentence
# 0  واندیشهٔ  NOUN                 0
# 1     فردات  NOUN                 0
# 2      سودا  NOUN                 0
# 3      نیست  VERB                11
#    word      tag  ordered sentence
# 3    دم     NOUN                 0
# 4   دلت  NOUN,EZ                 1
# 0  ضایع      ADJ                 2
# 5  شیدا      ADJ                 2
# 2   این      DET                 7
# 1   مکن     VERB                11
# 6  نیست     VERB                11
#    word   tag  ordered sentence
# 1  باقی  NOUN                 0
# 2   عمر  NOUN                 0
# 3   بها  NOUN                 0
# 4  پیدا   ADJ                 2
# 0  کاین  PRON                 6
# 5  نیست  VERB                11
#      word      tag  ordered sentence
# 3     تفت     NOUN                 0
# 1    عالم  NOUN,EZ                 1
# 2  روحانی   ADJ,EZ                 3
# 0    آمده     VERB                11
#     word   tag  ordered sentence
# 0  حیران   ADJ                 2
# 2    پنج   NUM                 9
# 3   چهار   NUM                 9
# 4     شش   NUM                 9
# 5    هفت   NUM                 9
# 1    شده  VERB                11
#       word      tag  ordered sentence
# 0       می  NOUN,EZ                 1
# 1      نوش      ADJ                 2
# 3      کجا      ADV                 4
# 2    ندانی     VERB                11
# 4  آمده‌ای     VERB                11
#         word   tag  ordered sentence
# 2      ندانی  NOUN                 0
# 0        خوش   ADJ                 2
# 3        کجا   ADV                 4
# 1        باش  VERB                11
# 4  خواهی_رفت  VERB                11
#     word      tag  ordered sentence
# 1    فلک     NOUN                 0
# 2  خرابی     NOUN                 0
# 0    چرخ  NOUN,EZ                 1
# 3  کینهٔ  NOUN,EZ                 1
# 4   توست     VERB                11
#        word      tag  ordered sentence
# 0  بیدادگری  NOUN,EZ                 1
# 1     شیوهٔ  NOUN,EZ                 1
# 2   دیرینهٔ  NOUN,EZ                 1
# 3      توست     VERB                11
#       word      tag  ordered sentence
# 0      خاک     NOUN                 0
# 1     سینه  NOUN,EZ                 1
# 2       تو     PRON                 6
# 3  بشکافند     VERB                11
#     word      tag  ordered sentence
# 2  قیمتی     NOUN                 0
# 1   گوهر  NOUN,EZ                 1
# 3  سینهٔ  NOUN,EZ                 1
# 0     بس      ADV                 4
# 4   توست     VERB                11
#      word   tag  ordered sentence
# 0      دل  NOUN                 0
# 2   زمانه  NOUN                 0
# 4  غمناکت  NOUN                 0
# 1      چو   ADV                 4
# 3  می‌کند  VERB                11
#    word      tag  ordered sentence
# 2    تن     NOUN                 0
# 4  پاکت     NOUN                 0
# 3  روان  NOUN,EZ                 1
# 0  ناگه      ADV                 4
# 1  برود     VERB                11
#    word      tag  ordered sentence
# 4  روزی     NOUN                 0
# 0  سبزه  NOUN,EZ                 1
# 1  نشین      ADJ                 2
# 2   خوش      ADJ                 2
# 5   چند      DET                 7
# 3   بزی     VERB                11
#    word   tag  ordered sentence
# 0   زآن  NOUN                 0
# 2  سبزه  NOUN                 0
# 3   دمد  NOUN                 0
# 4  خاکت  NOUN                 0
# 1   پیش   ADV                 4
#     word   tag  ordered sentence
# 1    بحر  NOUN                 0
# 2   وجود  NOUN                 0
# 5   نهفت  NOUN                 0
# 4  بیرون   ADV                 4
# 0    این   DET                 7
# 3   آمده  VERB                11
#     word      tag  ordered sentence
# 0     کس     NOUN                 0
# 3   گوهر     NOUN                 0
# 4  تحقیق  NOUN,EZ                 1
# 5   بسفت      ADJ                 2
# 2    این      DET                 7
# 1   نیست     VERB                11
#     word      tag  ordered sentence
# 1     کس     NOUN                 0
# 2   سخنی     NOUN                 0
# 4   سودا     NOUN                 0
# 3     سر  NOUN,EZ                 1
# 0     هر      DET                 7
# 5  گفتند     VERB                11
#        word   tag  ordered sentence
# 0       زآن  NOUN                 0
# 1       روی  NOUN                 0
# 3        کس  NOUN                 0
# 2       هست  VERB                11
# 4  نمی‌داند  VERB                11
# 5       گفت  VERB                11
#       word     tag  ordered sentence
# 1     کوزه    NOUN                 0
# 4     زاری    NOUN                 0
# 3     عاشق  ADJ,EZ                 3
# 2       من    PRON                 6
# 0      این     DET                 7
# 5  بوده‌ست    VERB                11
#       word      tag  ordered sentence
# 3    نگاری     NOUN                 0
# 0      بند  NOUN,EZ                 1
# 1       سر  NOUN,EZ                 1
# 2      زلف  NOUN,EZ                 1
# 4  بوده‌ست     VERB                11
#       word      tag  ordered sentence
# 1     دسته     NOUN                 0
# 2     گردن  NOUN,EZ                 1
# 3       او     PRON                 6
# 0      این      DET                 7
# 4  می‌بینی     VERB                11
#       word      tag  ordered sentence
# 2     یاری     NOUN                 0
# 1     گردن  NOUN,EZ                 1
# 0  دستی‌ست     VERB                11
# 3  بوده‌ست     VERB                11
#         word   tag  ordered sentence
# 1       کوزه  NOUN                 0
# 2   آبخوارهٔ  NOUN                 0
# 0        این   DET                 7
# 3  مزدوری‌ست  VERB                11
#         word      tag  ordered sentence
# 2         دل     NOUN                 0
# 0      دیدهٔ  NOUN,EZ                 1
# 1       شاهی      ADJ                 2
# 3  دستوری‌ست     VERB                11
#         word   tag  ordered sentence
# 1      کاسهٔ  NOUN                 0
# 2         می  NOUN                 0
# 3         کف  NOUN                 0
# 0         هر   DET                 7
# 4  مخموری‌ست  VERB                11
#         word      tag  ordered sentence
# 1       مستی     NOUN                 0
# 2         لب     NOUN                 0
# 0       عارض  NOUN,EZ                 1
# 3  مستوری‌ست     VERB                11
#    word   tag  ordered sentence
# 1  کهنه  NOUN                 0
# 2  رباط  NOUN                 0
# 3  عالم  NOUN                 0
# 4   نام  NOUN                 0
# 0   این   DET                 7
# 5   است  VERB                11
#       word      tag  ordered sentence
# 2      صبح     NOUN                 0
# 3      شام     NOUN                 0
# 0  وآرامگه  NOUN,EZ                 1
# 1     ابلق  NOUN,EZ                 1
# 4      است     VERB                11
#       word   tag  ordered sentence
# 1  واماندۀ  NOUN                 0
# 3    جمشید  NOUN                 0
# 2       صد   NUM                 9
# 0  بزمی‌ست  VERB                11
# 4      است  VERB                11
#        word      tag  ordered sentence
# 3     بهرام     NOUN                 0
# 1  تکیه‌گاه  NOUN,EZ                 1
# 2        صد      NUM                 9
# 0   قصری‌ست     VERB                11
# 4       است     VERB                11
#    word      tag  ordered sentence
# 4   روز     NOUN                 0
# 6   عمر     NOUN                 0
# 5  نوبت  NOUN,EZ                 1
# 0   این      DET                 7
# 1    یک      NUM                 9
# 2    دو      NUM                 9
# 3    سه      NUM                 9
# 7  گذشت     VERB                11
#      word   tag  ordered sentence
# 0      آب  NOUN                 0
# 1  جویبار  NOUN                 0
# 2     باد  NOUN                 0
# 3     دشت  NOUN                 0
#    word      tag  ordered sentence
# 3   روز     NOUN                 0
# 5   یاد     NOUN                 0
# 1    غم  NOUN,EZ                 1
# 0  هرگز      ADV                 4
# 4   مرا     PRON                 6
# 2    دو      NUM                 9
# 6  نگشت     VERB                11
#         word   tag  ordered sentence
# 0       روزی  NOUN                 0
# 2       روزی  NOUN                 0
# 1  نیامده‌ست  VERB                11
# 3       گذشت  VERB                11
#     word      tag  ordered sentence
# 3  نوروز     NOUN                 0
# 0   چهرۀ  NOUN,EZ                 1
# 1     گل  NOUN,EZ                 1
# 2   نسیم  NOUN,EZ                 1
# 4    خوش      ADJ                 2
# 5    است     VERB                11
#        word      tag  ordered sentence
# 1       چمن     NOUN                 0
# 2  دل‌افروز     NOUN                 0
# 0       صحن  NOUN,EZ                 1
# 3       خوش      ADJ                 2
# 4       است     VERB                11
#    word      tag  ordered sentence
# 0    دی     NOUN                 0
# 3    چه     NOUN                 0
# 1  گذشت  NOUN,EZ                 1
# 5   خوش      ADJ                 2
# 4  گویی      ADV                 4
# 2    هر      DET                 7
# 6  نیست     VERB                11
#     word   tag  ordered sentence
# 2     دی  NOUN                 0
# 0    خوش   ADJ                 2
# 5    خوش   ADJ                 2
# 4  امروز   ADV                 4
# 1    باش  VERB                11
# 3    مگو  VERB                11
# 6    است  VERB                11
#       word   tag  ordered sentence
# 3      لیل  NOUN                 0
# 4    نهاری  NOUN                 0
# 0      پیش   ADV                 4
# 1       من  PRON                 6
# 2       تو  PRON                 6
# 5  بوده‌ست  VERB                11
#        word      tag  ordered sentence
# 1       فلک     NOUN                 0
# 2     بکاری     NOUN                 0
# 0    گردنده  NOUN,EZ                 1
# 3  بوده_است     VERB                11
#    word      tag  ordered sentence
# 5  زمین     NOUN                 0
# 1   قدم  NOUN,EZ                 1
# 2   نهی  NOUN,EZ                 1
# 4   روی  NOUN,EZ                 1
# 0  هرجا      ADV                 4
# 3    تو     PRON                 6
#       word      tag  ordered sentence
# 2      چشم     NOUN                 0
# 3    نگاری     NOUN                 0
# 1    مردمک  NOUN,EZ                 1
# 0       آن     PRON                 6
# 4  بوده‌ست     VERB                11
#      word      tag  ordered sentence
# 1     زنم     NOUN                 0
# 3  دریاها     NOUN                 0
# 4     خشت     NOUN                 0
# 2     روی  NOUN,EZ                 1
# 0     چند      DET                 7
#         word   tag  ordered sentence
# 2  بت‌پرستان  NOUN                 0
# 3       کنشت  NOUN                 0
# 0      بیزار   ADJ                 2
# 1        شدم  VERB                11
#         word   tag  ordered sentence
# 0       خیام  NOUN                 0
# 2      دوزخی  NOUN                 0
# 1        گفت  VERB                11
# 3  خواهد_بود  VERB                11
#    word   tag  ordered sentence
# 1  دوزخ  NOUN                 0
# 3  بهشت  NOUN                 0
# 0   رفت  VERB                11
# 2   آمد  VERB                11
#        word      tag  ordered sentence
# 1  پیاله‌ای     NOUN                 0
# 0     ترکیب  NOUN,EZ                 1
# 2        هم     PRON                 6
# 3     پیوست     VERB                11
#        word      tag  ordered sentence
# 0    بشکستن  NOUN,EZ                 1
# 2       روا      ADJ                 2
# 4       مست      ADJ                 2
# 1        آن     PRON                 6
# 3  نمی‌دارد     VERB                11
#      word      tag  ordered sentence
# 1      سر     NOUN                 0
# 3  نازنین     NOUN                 0
# 5     دست     NOUN                 0
# 2     پای  NOUN,EZ                 1
# 4      سر  NOUN,EZ                 1
# 0   چندین      DET                 7
#     word   tag  ordered sentence
# 0    مهر  NOUN                 0
# 2    کین  NOUN                 0
# 3   شکست  NOUN                 0
# 1  پیوست  VERB                11
#      word      tag  ordered sentence
# 0   ترکیب  NOUN,EZ                 1
# 1   طبایع  NOUN,EZ                 1
# 3     کام  NOUN,EZ                 1
# 2      چو      ADV                 4
# 4      تو     PRON                 6
# 5  دمی‌ست     VERB                11
#       word   tag  ordered sentence
# 0      شاد   ADJ                 2
# 2       تو  PRON                 6
# 1      بزی  VERB                11
# 3  ستمی‌ست  VERB                11
#   word      tag  ordered sentence
# 1  خرد     NOUN                 0
# 0  اهل  NOUN,EZ                 1
# 3  اصل  NOUN,EZ                 1
# 4   تن  NOUN,EZ                 1
# 5   تو     PRON                 6
# 2  باش     VERB                11
#      word   tag  ordered sentence
# 0    گردی  NOUN                 0
# 1   نسیمی  NOUN                 0
# 2   غباری  NOUN                 0
# 3  دمی‌ست  VERB                11
#     word      tag  ordered sentence
# 0    ابر     NOUN                 0
# 1  نوروز     NOUN                 0
# 3   لاله     NOUN                 0
# 2     رخ  NOUN,EZ                 1
# 4   بشست     VERB                11
#     word      tag  ordered sentence
# 2   باده     NOUN                 0
# 1    جام  NOUN,EZ                 1
# 4    عزم  NOUN,EZ                 1
# 5   درست      ADJ                 2
# 0  برخیز     VERB                11
# 3     کن     VERB                11
#       word      tag  ordered sentence
# 0     سبزه     NOUN                 0
# 2  تماشاگه  NOUN,EZ                 1
# 1    امروز      ADV                 4
# 3     توست     VERB                11
#       word   tag  ordered sentence
# 2      خاک  NOUN                 0
# 0     فردا   ADV                 4
# 1      همه  PRON                 6
# 3       تو  PRON                 6
# 4  برخواهد  VERB                11
# 5      رست  VERB                11
#     word      tag  ordered sentence
# 2    راه     NOUN                 0
# 3  بستان     NOUN                 0
# 0   بلبل  NOUN,EZ                 1
# 1    مست      ADJ                 2
# 4   یافت     VERB                11
#     word      tag  ordered sentence
# 0     گل     NOUN                 0
# 2   باده     NOUN                 0
# 1    جام  NOUN,EZ                 1
# 3  خندان      ADJ                 2
# 4   یافت     VERB                11
#    word      tag  ordered sentence
# 3  گوشم     NOUN                 0
# 1  زبان  NOUN,EZ                 1
# 2   حال      ADV                 4
# 0   آمد     VERB                11
# 4   گفت     VERB                11
#     word   tag  ordered sentence
# 1    عمر  NOUN                 0
# 0  دریاب  VERB                11
# 2   رفته  VERB                11
# 3  نتوان  VERB                11
# 4   یافت  VERB                11
#      word      tag  ordered sentence
# 0     چرخ     NOUN                 0
# 3  خردمند     NOUN                 0
# 1     کام  NOUN,EZ                 1
# 2      یک      NUM                 9
# 4    نگشت     VERB                11
#         word   tag  ordered sentence
# 0   خواهی_تو  NOUN                 0
# 1        فلک  NOUN                 0
# 3        شمر  NOUN                 0
# 2        هفت   NUM                 9
# 4  خواهی_هشت  VERB                11
#      word     tag  ordered sentence
# 1     مرد    NOUN                 0
# 2  آرزوها    NOUN                 0
# 3     همه  DET,EZ                 8
# 4     هشت     NUM                 9
# 0    باید    VERB                11
#    word   tag  ordered sentence
# 1   مور  NOUN                 0
# 3   گور  NOUN                 0
# 5   گرگ  NOUN                 0
# 6   دشت  NOUN                 0
# 0    چه   DET                 7
# 4    چه   DET                 7
# 2  خورد  VERB                11
#     word      tag  ordered sentence
# 0   لاله     NOUN                 0
# 3    گیر     NOUN                 0
# 4    دست     NOUN                 0
# 1  نوروز  NOUN,EZ                 1
# 2    قدح  NOUN,EZ                 1
#        word   tag  ordered sentence
# 0  لاله‌رخی  NOUN                 0
# 2      فرصت  NOUN                 0
# 1        تو  PRON                 6
# 3       هست  VERB                11
#    word      tag  ordered sentence
# 0    می     NOUN                 0
# 1   نوش     NOUN                 0
# 2  خرمی     NOUN                 0
# 4   چرخ  NOUN,EZ                 1
# 5   کهن      ADJ                 2
# 3   این      DET                 7
#      word   tag  ordered sentence
# 3     خاک  NOUN                 0
# 5     پست  NOUN                 0
# 0   ناگاه   ADV                 4
# 2      چو   ADV                 4
# 1      تو  PRON                 6
# 4  گرداند  VERB                11
#     word   tag  ordered sentence
# 1  حقیقت  NOUN                 0
# 2   یقین  NOUN                 0
# 3    دست  NOUN                 0
# 0   نیست  VERB                11
#     word      tag  ordered sentence
# 2     شک     NOUN                 0
# 4    عمر     NOUN                 0
# 1   امید  NOUN,EZ                 1
# 3    همه   DET,EZ                 8
# 0  نتوان     VERB                11
# 5   نشست     VERB                11
#     word      tag  ordered sentence
# 2     می     NOUN                 0
# 4    دست     NOUN                 0
# 1    جام  NOUN,EZ                 1
# 3     کف  NOUN,EZ                 1
# 0  ننهیم     VERB                11
#       word      tag  ordered sentence
# 1      مرد     NOUN                 0
# 0  بی‌خبری  NOUN,EZ                 1
# 3    هشیار      ADJ                 2
# 4      مست      ADJ                 2
# 2       چه      ADV                 4
#    word   tag  ordered sentence
# 3   باد  NOUN                 0
# 4   دست  NOUN                 0
# 1  هرچه   ADV                 4
# 0  نیست  VERB                11
# 2   هست  VERB                11
#     word   tag  ordered sentence
# 3  نقصان  NOUN                 0
# 4   شکست  NOUN                 0
# 1   هرچه   ADV                 4
# 0    هست  VERB                11
# 2    هست  VERB                11
#     word   tag  ordered sentence
# 3   عالم  NOUN                 0
# 0  انگار   ADV                 4
# 1   هرچه   ADV                 4
# 2    هست  VERB                11
# 4   نیست  VERB                11
#     word   tag  ordered sentence
# 0  پندار  NOUN                 0
# 3   عالم  NOUN                 0
# 1   هرچه   ADV                 4
# 2   نیست  VERB                11
# 4    هست  VERB                11
#         word      tag  ordered sentence
# 0       خاکی     NOUN                 0
# 4  نادانی‌ست     NOUN                 0
# 1        زیر  NOUN,EZ                 1
# 2        پای  NOUN,EZ                 1
# 3         هر      DET                 7
#         word      tag  ordered sentence
# 1      صنمیّ     NOUN                 0
# 2      چهرهٔ     NOUN                 0
# 0        کفّ  NOUN,EZ                 1
# 3  جانانی‌ست     VERB                11
#         word   tag  ordered sentence
# 1        خشت  NOUN                 0
# 2     کنگرهٔ  NOUN                 0
# 0         هر   DET                 7
# 3  ایوانی‌ست  VERB                11
#         word      tag  ordered sentence
# 1       وزیر     NOUN                 0
# 2         سر     NOUN                 0
# 0      انگشت  NOUN,EZ                 1
# 3  سلطانی‌ست     VERB                11
#      word      tag  ordered sentence
# 0  دارنده     NOUN                 0
# 2   ترکیب  NOUN,EZ                 1
# 3   طبایع  NOUN,EZ                 1
# 1      چو      ADV                 4
# 4   آراست     VERB                11
#       word      tag  ordered sentence
# 2  اوفکندش     NOUN                 0
# 4     کاست     NOUN                 0
# 0      بهر  NOUN,EZ                 1
# 3       کم      ADJ                 2
# 1       چه      DET                 7
#     word   tag  ordered sentence
# 2  شکستن  NOUN                 0
# 3    بهر  NOUN                 0
# 0    نیک   ADV                 4
# 4     چه   ADV                 4
# 1    آمد  VERB                11
# 5    بود  VERB                11
#     word   tag  ordered sentence
# 3    صور  NOUN                 0
# 4    عیب  NOUN                 0
# 5   راست  NOUN                 0
# 0    نیک   ADJ                 2
# 2    این   DET                 7
# 1  نیامد  VERB                11
#     word      tag  ordered sentence
# 2    کسی     NOUN                 0
# 3     ره     NOUN                 0
# 0   پردۀ  NOUN,EZ                 1
# 1  اسرار  NOUN,EZ                 1
# 4   نیست     VERB                11
#      word      tag  ordered sentence
# 0     زین     NOUN                 0
# 1   تعبیه     NOUN                 0
# 3  هیچ‌کس     NOUN                 0
# 2     جان  NOUN,EZ                 1
# 4     آگه      ADJ                 2
# 5    نیست     VERB                11
#      word      tag  ordered sentence
# 1     خاک     NOUN                 0
# 3  منزلگه     NOUN                 0
# 0      دل  NOUN,EZ                 1
# 2     هیچ      DET                 7
# 4    نیست     VERB                11
#        word   tag  ordered sentence
# 0        می  NOUN                 0
# 2      چنین  NOUN                 0
# 3  فسانه‌ها  NOUN                 0
# 4      کوته   ADJ                 2
# 1       خور  VERB                11
# 5      نیست  VERB                11
#       word   tag  ordered sentence
# 0     خواب  NOUN                 0
# 3  خردمندی  NOUN                 0
# 2      مرا  PRON                 6
# 1      بدم  VERB                11
# 4      گفت  VERB                11
#     word      tag  ordered sentence
# 1    کسی     NOUN                 0
# 3   شادی     NOUN                 0
# 0   خواب  NOUN,EZ                 1
# 2     گل  NOUN,EZ                 1
# 4  نشکفت     VERB                11
#    word   tag  ordered sentence
# 0  کاری  NOUN                 0
# 3   اجل  NOUN                 0
# 1    چه   DET                 7
# 2   کنی  VERB                11
# 4  باشد  VERB                11
# 5  جفت‌  VERB                11
#       word      tag  ordered sentence
# 0       می     NOUN                 0
# 3      خاک     NOUN                 0
# 5      خفت     NOUN                 0
# 2      زیر  NOUN,EZ                 1
# 1      خور     VERB                11
# 4  می‌باید     VERB                11
#        word      tag  ordered sentence
# 0  دایره‌ای     NOUN                 0
# 2      رفتن  NOUN,EZ                 1
# 1       آمد     VERB                11
# 3      ماست     VERB                11
#       word   tag  ordered sentence
# 2    بدایت  NOUN                 0
# 4    نهایت  NOUN                 0
# 1       نه   ADV                 4
# 3       نه   ADV                 4
# 0       او  PRON                 6
# 5  پیدا‌ست  VERB                11
#       word      tag  ordered sentence
# 0       کس     NOUN                 0
# 2      دمی     NOUN                 0
# 4     معنی  NOUN,EZ                 1
# 5     راست      ADJ                 2
# 3      این      DET                 7
# 1  می‌نزند     VERB                11
#     word   tag  ordered sentence
# 0   کاین  NOUN                 0
# 1   آمدن  NOUN                 0
# 3   رفتن  NOUN                 0
# 2    کجا   ADV                 4
# 4  کجاست  VERB                11
#    word      tag  ordered sentence
# 1  بهار     NOUN                 0
# 2   بتی     NOUN                 0
# 4  سرشت     NOUN                 0
# 0   فصل  NOUN,EZ                 1
# 3   حور  NOUN,EZ                 1
#    word      tag  ordered sentence
# 1  ساغر     NOUN                 0
# 2    می     NOUN                 0
# 6   کشت     NOUN                 0
# 5    لب  NOUN,EZ                 1
# 4   مرا     PRON                 6
# 0    یک      NUM                 9
# 3   دهد     VERB                11
#    word      tag  ordered sentence
# 3  عامه     NOUN                 0
# 2   نزد  NOUN,EZ                 1
# 6   زشت      ADJ                 2
# 4   این     PRON                 6
# 0    هر      DET                 7
# 1   چند      DET                 7
# 5  باشد     VERB                11
#    word      tag  ordered sentence
# 0    سگ     NOUN                 0
# 1     ز     NOUN                 0
# 6  بهشت     NOUN                 0
# 5   نام  NOUN,EZ                 1
# 2    من     PRON                 6
# 3   است     VERB                11
# 4   برم     VERB                11
#         word      tag  ordered sentence
# 1        روح  NOUN,EZ                 1
# 2        جدا      ADJ                 2
# 0      دریاب     VERB                11
# 3  خواهی_رفت     VERB                11
#         word      tag  ordered sentence
# 2        فنا     NOUN                 0
# 0       پردۀ  NOUN,EZ                 1
# 1      اسرار  NOUN,EZ                 1
# 3  خواهی_رفت     VERB                11
#       word      tag  ordered sentence
# 0       می  NOUN,EZ                 1
# 1      نوش      ADJ                 2
# 3      کجا      ADV                 4
# 2    ندانی     VERB                11
# 4  آمده‌ای     VERB                11
#         word   tag  ordered sentence
# 2      ندانی  NOUN                 0
# 0        خوش   ADJ                 2
# 3        کجا   ADV                 4
# 1        باش  VERB                11
# 4  خواهی_رفت  VERB                11
#      word   tag  ordered sentence
# 0    ساقی  NOUN                 0
# 1      گل  NOUN                 0
# 2    سبزه  NOUN                 0
# 4  طربناک   ADJ                 2
# 3      بس   ADV                 4
# 5  شده‌ست  VERB                11
#         word     tag  ordered sentence
# 2        خاک    NOUN                 0
# 1  هفتهٔ دگر  ADJ,EZ                 3
# 0      دریاب    VERB                11
# 3     شده‌ست    VERB                11
#      word      tag  ordered sentence
# 2     گلی     NOUN                 0
# 4  درنگری     NOUN                 0
# 0      می  NOUN,EZ                 1
# 1     نوش      ADJ                 2
# 3    بچین     VERB                11
#      word      tag  ordered sentence
# 1     خاک     NOUN                 0
# 3    سبزه     NOUN                 0
# 4   خاشاک     NOUN                 0
# 0      گل  NOUN,EZ                 1
# 2  شده‌ست     VERB                11
# 5  شده‌ست     VERB                11
#       word      tag  ordered sentence
# 0  عمری‌ست  NOUN,EZ                 1
# 2     تیره      ADJ                 2
# 5     راست      ADJ                 2
# 4       نه      ADV                 4
# 1      مرا     PRON                 6
# 3  کاری‌ست     VERB                11
#      word      tag  ordered sentence
# 5    کاست     NOUN                 0
# 0    محنت  NOUN,EZ                 1
# 4      کم      ADJ                 2
# 3    راحت      ADV                 4
# 1     همه     PRON                 6
# 2  افزوده     VERB                11
#      word      tag  ordered sentence
# 1    ایزد     NOUN                 0
# 3   اسباب     NOUN                 0
# 0     شکر  NOUN,EZ                 1
# 2    آنچه     PRON                 6
# 4  بلا‌ست     VERB                11
#        word   tag  ordered sentence
# 1        کس  NOUN                 0
# 0        ما  PRON                 6
# 2       دگر  PRON                 6
# 3  نمی‌باید  VERB                11
# 4     خواست  VERB                11
#      word      tag  ordered sentence
# 1      گل     NOUN                 0
# 3  جویبار     NOUN                 0
# 4     کشت     NOUN                 0
# 0     فصل  NOUN,EZ                 1
# 2     طرف  NOUN,EZ                 1
#        word   tag  ordered sentence
# 3       اهل  NOUN                 0
# 4     لعبتی  NOUN                 0
# 5  حور‌سرشت  NOUN                 0
# 0        یک   NUM                 9
# 1        دو   NUM                 9
# 2        سه   NUM                 9
#          word   tag  ordered sentence
# 2         قدح  NOUN                 0
# 3  باده‌نوشان  NOUN                 0
# 4        صبوح  NOUN                 0
# 0         پیش   ADV                 4
# 1          آر  VERB                11
#       word   tag  ordered sentence
# 1  مسجد‌ند  NOUN                 0
# 3     کنشت  NOUN                 0
# 0    آسوده   ADJ                 2
# 2     فارغ   ADJ                 2
#       word      tag  ordered sentence
# 1      بقا     NOUN                 0
# 3     بختت     NOUN                 0
# 0      شاخ  NOUN,EZ                 1
# 2      بیخ  NOUN,EZ                 1
# 4  رسته‌ست     VERB                11
#     word      tag  ordered sentence
# 2   عمرْ     NOUN                 0
# 3  لباسی     NOUN                 0
# 0     تن  NOUN,EZ                 1
# 1     تو     PRON                 6
# 4   چُست     VERB                11
# 5    است     VERB                11
#          word      tag  ordered sentence
# 0    خیمهٔ تن     NOUN                 0
# 1  سایبانی‌ست  NOUN,EZ                 1
# 2         ترا     PRON                 6
#       word   tag  ordered sentence
# 0     تکیه  NOUN                 0
# 2  چارمیخش  NOUN                 0
# 3      سست   ADJ                 2
# 1      مکن  VERB                11
# 4      است  VERB                11
#     word      tag  ordered sentence
# 2   بهشت     NOUN                 0
# 1   کسان  NOUN,EZ                 1
# 3    حور  NOUN,EZ                 1
# 4    خوش      ADJ                 2
# 0  گویند     VERB                11
# 5    است     VERB                11
#       word      tag  ordered sentence
# 3    انگور     NOUN                 0
# 2       آب  NOUN,EZ                 1
# 4      خوش      ADJ                 2
# 0       من     PRON                 6
# 1  می‌گویم     VERB                11
# 5      است     VERB                11
#    word   tag  ordered sentence
# 1   نقد  NOUN                 0
# 3   دست  NOUN                 0
# 5  نسیه  NOUN                 0
# 0   این   DET                 7
# 4    آن   DET                 7
# 2  بگیر  VERB                11
# 6  بدار  VERB                11
#       word      tag  ordered sentence
# 0  که‌آواز     NOUN                 0
# 1      دهل     NOUN                 0
# 2    شنیدن     NOUN                 0
# 3      دور  NOUN,EZ                 1
# 4      خوش      ADJ                 2
# 5      است     VERB                11
#     word   tag  ordered sentence
# 2  دوزخی  NOUN                 0
# 4    مست   ADJ                 2
# 1    مرا  PRON                 6
# 0  گویند  VERB                11
# 3   باشد  VERB                11
#       word      tag  ordered sentence
# 2       دل     NOUN                 0
# 0  قولی‌ست  NOUN,EZ                 1
# 1     خلاف      ADJ                 2
# 3       آن     PRON                 6
# 4    نتوان     VERB                11
# 5      بست     VERB                11
#       word   tag  ordered sentence
# 0     عاشق  NOUN                 0
# 2     دوزخ  NOUN                 0
# 1  میخواره   ADJ                 2
# 3    باشند  VERB                11
#     word      tag  ordered sentence
# 2   بهشت     NOUN                 0
# 5    دست     NOUN                 0
# 4     کف  NOUN,EZ                 1
# 0   فردا      ADV                 4
# 3  همچون      ADV                 4
# 1   بینی     VERB                11
#     word   tag  ordered sentence
# 4   سرشت  NOUN                 0
# 0     من  PRON                 6
# 3    مرا  PRON                 6
# 1    هیچ   DET                 7
# 2  ندانم  VERB                11
#    word      tag  ordered sentence
# 1  بهشت     NOUN                 0
# 0   اهل  NOUN,EZ                 1
# 3  دوزخ  NOUN,EZ                 1
# 4   زشت      ADJ                 2
# 2   کرد     VERB                11
#     word      tag  ordered sentence
# 0   جامی     NOUN                 0
# 1    بتی     NOUN                 0
# 2  بربطی     NOUN                 0
# 4    کشت     NOUN                 0
# 3     لب  NOUN,EZ                 1
#    word      tag  ordered sentence
# 1  هرسه     NOUN                 0
# 3   نقد     NOUN                 0
# 6  بهشت     NOUN                 0
# 5  نسیه  NOUN,EZ                 1
# 2   مرا     PRON                 6
# 4    تو     PRON                 6
# 0   این      DET                 7
#      word      tag  ordered sentence
# 0   مهتاب     NOUN                 0
# 1     نور     NOUN                 0
# 3      شب     NOUN                 0
# 2    دامن  NOUN,EZ                 1
# 4  بشکافت     VERB                11
#     word   tag  ordered sentence
# 0     می  NOUN                 0
# 2    دمی  NOUN                 0
# 3   بهتر   ADJ                 2
# 4    این  PRON                 6
# 1    نوش  VERB                11
# 5  نتوان  VERB                11
#      word      tag  ordered sentence
# 2  میندیش     NOUN                 0
# 4     بسی     NOUN                 0
# 3   مهتاب  NOUN,EZ                 1
# 0     خوش      ADJ                 2
# 1     باش     VERB                11
#          word      tag  ordered sentence
# 1         خاک     NOUN                 0
# 4  خواهد_تافت     NOUN                 0
# 0          سر  NOUN,EZ                 1
# 2          یک      NUM                 9
# 3          یک      NUM                 9
#     word      tag  ordered sentence
# 0     می     NOUN                 0
# 1  خوردن     NOUN                 0
# 3   بودن  NOUN,EZ                 1
# 4   آیین  NOUN,EZ                 1
# 2    شاد      ADJ                 2
# 5     من     PRON                 6
# 6    است     VERB                11
#    word      tag  ordered sentence
# 1  بودن     NOUN                 0
# 2   کفر     NOUN                 0
# 4   دین     NOUN                 0
# 3   دین  NOUN,EZ                 1
# 0  فارغ      ADJ                 2
# 5    من     PRON                 6
# 6   است     VERB                11
#     word      tag  ordered sentence
# 2    دهر     NOUN                 0
# 1   عروس  NOUN,EZ                 1
# 3  کابین  NOUN,EZ                 1
# 4     تو     PRON                 6
# 0   گفتم     VERB                11
# 5   چیست     VERB                11
#     word      tag  ordered sentence
# 1     دل  NOUN,EZ                 1
# 4  کابین  NOUN,EZ                 1
# 2    خرم      ADJ                 2
# 3     تو     PRON                 6
# 5     من     PRON                 6
# 0   گفتا     VERB                11
# 6    است     VERB                11
#     word   tag  ordered sentence
# 0     می  NOUN                 0
# 4  صراحی  NOUN                 0
# 5    کان  NOUN                 0
# 2   مذاب   ADJ                 2
# 1    لعل   ADV                 4
# 3    است  VERB                11
# 6    است  VERB                11
#     word   tag  ordered sentence
# 0    جسم  NOUN                 0
# 2  پیاله  NOUN                 0
# 3  شرابش  NOUN                 0
# 4    جان  NOUN                 0
# 1    است  VERB                11
# 5    است  VERB                11
#      word      tag  ordered sentence
# 3      می     NOUN                 0
# 1     جام  NOUN,EZ                 1
# 2  بلورین      ADJ                 2
# 4   خندان      ADJ                 2
# 0      آن     PRON                 6
# 5     است     VERB                11
#     word      tag  ordered sentence
# 0   اشکی     NOUN                 0
# 3     دل     NOUN                 0
# 2    خون  NOUN,EZ                 1
# 5  پنهان      ADJ                 2
# 4     او     PRON                 6
# 1    است     VERB                11
# 6    است     VERB                11
#       word      tag  ordered sentence
# 0       می     NOUN                 0
# 2      عمر  NOUN,EZ                 1
# 3  جاودانی      ADJ                 2
# 4      این     PRON                 6
# 1      نوش     VERB                11
# 5      است     VERB                11
#     word      tag  ordered sentence
# 1  حاصلت     NOUN                 0
# 3  جوانی     NOUN                 0
# 2    دور  NOUN,EZ                 1
# 0    خود     PRON                 6
# 4    این     PRON                 6
# 5    است     VERB                11
#     word      tag  ordered sentence
# 1     گل     NOUN                 0
# 2   باده     NOUN                 0
# 0  هنگام  NOUN,EZ                 1
# 3  یاران  NOUN,EZ                 1
# 4  سرمست      ADJ                 2
#       word   tag  ordered sentence
# 2      دمی  NOUN                 0
# 3  زندگانی  NOUN                 0
# 0      خوش   ADJ                 2
# 4      این  PRON                 6
# 1      باش  VERB                11
# 5      است  VERB                11
#    word      tag  ordered sentence
# 0  نیکی     NOUN                 0
# 1   بدی     NOUN                 0
# 3   بشر     NOUN                 0
# 2  نهاد  NOUN,EZ                 1
# 4   است     VERB                11
#    word   tag  ordered sentence
# 0  شادی  NOUN                 0
# 1   غمی  NOUN                 0
# 2   قضا  NOUN                 0
# 3   قدر  NOUN                 0
# 4   است  VERB                11
#     word      tag  ordered sentence
# 0    چرخ     NOUN                 0
# 2  حواله     NOUN                 0
# 4    عقل     NOUN                 0
# 3     ره  NOUN,EZ                 1
# 1    مکن     VERB                11
#         word   tag  ordered sentence
# 0        چرخ  NOUN                 0
# 3        بار  NOUN                 0
# 4  بیچاره‌تر   ADJ                 2
# 1         تو  PRON                 6
# 2       هزار   NUM                 9
# 5        است  VERB                11
#         word   tag  ordered sentence
# 1       دشتی  NOUN                 0
# 2  لاله‌زاری  NOUN                 0
# 0         هر   DET                 7
# 3    بوده‌ست  VERB                11
#       word      tag  ordered sentence
# 2  شهریاری     NOUN                 0
# 0     سرخی  NOUN,EZ                 1
# 1      خون  NOUN,EZ                 1
# 3  بوده‌ست     VERB                11
#       word      tag  ordered sentence
# 2    بنفشه     NOUN                 0
# 3     زمین     NOUN                 0
# 1      شاخ  NOUN,EZ                 1
# 0       هر      DET                 7
# 4  می‌روید     VERB                11
#       word      tag  ordered sentence
# 2    نگاری     NOUN                 0
# 1       رخ  NOUN,EZ                 1
# 0  خالی‌ست     VERB                11
# 3  بوده‌ست     VERB                11
#       word      tag  ordered sentence
# 1      ذره     NOUN                 0
# 2      خاک  NOUN,EZ                 1
# 3    زمینی      ADJ                 2
# 0       هر      DET                 7
# 4  بوده‌ست     VERB                11
#       word   tag  ordered sentence
# 3      تاج  NOUN                 0
# 4    نگینی  NOUN                 0
# 0      پیش   ADV                 4
# 1       من  PRON                 6
# 2       تو  PRON                 6
# 5  بوده‌ست  VERB                11
#      word      tag  ordered sentence
# 0     گرد     NOUN                 0
# 2  نازنین     NOUN                 0
# 4    فشان     NOUN                 0
# 1      رخ  NOUN,EZ                 1
# 3    آزرم  NOUN,EZ                 1
#       word      tag  ordered sentence
# 0      کآن     NOUN                 0
# 1       رخ  NOUN,EZ                 1
# 3  نازنینی      ADJ                 2
# 2      خوب   ADJ,EZ                 3
# 4  بوده‌ست     VERB                11
#       word     tag  ordered sentence
# 1     سبزه    NOUN                 0
# 3     جویی    NOUN                 0
# 2     کنار  ADV,EZ                 5
# 0       هر     DET                 7
# 4  رسته‌ست    VERB                11
#          word   tag  ordered sentence
# 1          لب  NOUN                 0
# 2  فرشته‌خویی  NOUN                 0
# 0        گویی   ADV                 4
# 3     رسته‌ست  VERB                11
#     word      tag  ordered sentence
# 0     پا     NOUN                 0
# 2   سبزه     NOUN                 0
# 3  خواری     NOUN                 0
# 1     سر  NOUN,EZ                 1
# 4   ننهی     VERB                11
#         word      tag  ordered sentence
# 1       سبزه     NOUN                 0
# 2        خاک     NOUN                 0
# 3  لاله‌رویی     NOUN                 0
# 0        کآن  NOUN,EZ                 1
# 4    رسته‌ست     VERB                11
#     word      tag  ordered sentence
# 2     می     NOUN                 0
# 3    ملک     NOUN                 0
# 4  کاووس     NOUN                 0
# 1  جرعهٔ  NOUN,EZ                 1
# 0     یک      NUM                 9
# 5    است     VERB                11
#    word      tag  ordered sentence
# 1  قباد     NOUN                 0
# 3   طوس     NOUN                 0
# 0   تخت  NOUN,EZ                 1
# 2  ملکت  NOUN,EZ                 1
# 4   است     VERB                11
#      word      tag  ordered sentence
# 1    ناله     NOUN                 0
# 2    رندی     NOUN                 0
# 4     زند     NOUN                 0
# 3  سحرگاه  NOUN,EZ                 1
# 0      هر      DET                 7
#      word      tag  ordered sentence
# 1  زاهدان     NOUN                 0
# 2   سالوس     NOUN                 0
# 0    طاعت  NOUN,EZ                 1
# 3     است     VERB                11
#     word   tag  ordered sentence
# 0    عمر  NOUN                 0
# 1     سر  NOUN                 0
# 3  شیرین   ADJ                 2
# 4    تلخ   ADJ                 2
# 2    رسد  VERB                11
#      word   tag  ordered sentence
# 0  پیمانه  NOUN                 0
# 4   بغداد  NOUN                 0
# 6     بلخ  NOUN                 0
# 2      پر   ADJ                 2
# 1      چو   ADV                 4
# 5      چه   DET                 7
# 3     شود  VERB                11
#   word   tag  ordered sentence
# 0   می  NOUN                 0
# 4  ماه  NOUN                 0
# 5  بسی   ADV                 4
# 2   من  PRON                 6
# 3   تو  PRON                 6
# 1  نوش  VERB                11
#     word   tag  ordered sentence
# 0   سَلخ  NOUN                 0
# 1  غٌرّه  NOUN                 0
# 3    غره  NOUN                 0
# 4    سلخ  NOUN                 0
# 2    آید  VERB                11
#    word      tag  ordered sentence
# 2   فضل     NOUN                 0
# 3  آداب     NOUN                 0
# 1  محیط  NOUN,EZ                 1
# 0  آنان     PRON                 6
# 4  شدند     VERB                11
# ...
# 0  نتیجهٔ  NOUN                 0
# 2    هفتی   ADJ                 2
# 1    چهار   NUM                 9
#    word   tag  ordered sentence
# 2  دایم  NOUN                 0
# 3  تفتی  NOUN                 0
# 0   هفت   NUM                 9
# 1  چهار   NUM                 9
#    word   tag  ordered sentence
# 0    می  NOUN                 0
# 3   بار  NOUN                 0
# 2  هزار   NUM                 9
# 1   خور  VERB                11
# 4  بیشت  VERB                11
# 5  گفتم  VERB                11
#     word   tag  ordered sentence
# 1  آمدنت  NOUN                 0
# 0    باز   ADV                 4
# 2   نیست  VERB                11
# 3   رفتی  VERB                11
# 4   رفتی  VERB                11
#     word      tag  ordered sentence
# 0   ایدل     NOUN                 0
# 3   معما     NOUN                 0
# 2  اسرار  NOUN,EZ                 1
# 1     تو     PRON                 6
# 4   نرسی     VERB                11
#      word      tag  ordered sentence
# 3    نرسی     NOUN                 0
# 0    نکته  NOUN,EZ                 1
# 1  زیرکان  NOUN,EZ                 1
# 2    دانا      ADJ                 2
#      word      tag  ordered sentence
# 2     لعل     NOUN                 0
# 3   بهشتی     NOUN                 0
# 1      می  NOUN,EZ                 1
# 0   اینجا      ADV                 4
# 4  می‌ساز     VERB                11
#     word   tag  ordered sentence
# 0  کانجا  NOUN                 0
# 1   بهشت  NOUN                 0
# 4   نرسی  NOUN                 0
# 3    رسی   ADJ                 2
# 2    است  VERB                11
#     word      tag  ordered sentence
# 1  حقیقت     NOUN                 0
# 4   سخنی     NOUN                 0
# 0   دوست  NOUN,EZ                 1
# 3     من     PRON                 6
# 2    شنو     VERB                11
#     word      tag  ordered sentence
# 4    تنی     NOUN                 0
# 0  بادهٔ  NOUN,EZ                 1
# 3    سیم  NOUN,EZ                 1
# 1    لعل      ADJ                 2
# 2    باش     VERB                11
#     word   tag  ordered sentence
# 0  کانکس  NOUN                 0
# 1   جهان  NOUN                 0
# 3  فراغت  NOUN                 0
# 2    کرد  VERB                11
# 4   دارد  VERB                11
#    word      tag  ordered sentence
# 0  سبلت     NOUN                 0
# 3   ریش  NOUN,EZ                 1
# 1   چون      ADV                 4
# 4    چو      ADV                 4
# 5   منی     PRON                 6
# 2  تویی     VERB                11
#      word      tag  ordered sentence
# 2  آرمیدن     NOUN                 0
# 1     جای  NOUN,EZ                 1
# 0     کاش      ADV                 4
# 3    بودی     VERB                11
#     word   tag  ordered sentence
# 1     ره  NOUN                 0
# 3  رسیدن  NOUN                 0
# 2    دور   ADJ                 2
# 0    این   DET                 7
# 4   بودی  VERB                11
#    word      tag  ordered sentence
# 4   سال     NOUN                 0
# 6   خاک     NOUN                 0
# 1    پی  NOUN,EZ                 1
# 5    دل  NOUN,EZ                 1
# 0   کاش      ADV                 4
# 2    صد      NUM                 9
# 3  هزار      NUM                 9
#     word   tag  ordered sentence
# 0   سبزه  NOUN                 0
# 1   امید  NOUN                 0
# 2  دمیدن  NOUN                 0
# 3   بودی  VERB                11
#    word      tag  ordered sentence
# 0   سنگ     NOUN                 0
# 4  کاشی     NOUN                 0
# 2   دوش  NOUN,EZ                 1
# 3  سبوی  NOUN,EZ                 1
# 1   زدم     VERB                11
#     word   tag  ordered sentence
# 0  سرمست  NOUN                 0
# 4  عیاشی  NOUN                 0
# 3    این   DET                 7
# 1    بدم  VERB                11
# 2   کردم  VERB                11
#      word      tag  ordered sentence
# 2     حال     NOUN                 0
# 4     سبو     NOUN                 0
# 1    زبان  NOUN,EZ                 1
# 0      من     PRON                 6
# 3  می‌گفت     VERB                11
#    word   tag  ordered sentence
# 4   چون   ADV                 4
# 0    من  PRON                 6
# 1    تو  PRON                 6
# 3    تو  PRON                 6
# 5    من  PRON                 6
# 2   بدم  VERB                11
# 6  باشی  VERB                11
#      word      tag  ordered sentence
# 1    امید     NOUN                 0
# 2     بری     NOUN                 0
# 3  یافتمی     NOUN                 0
# 0     شاخ  NOUN,EZ                 1
#      word      tag  ordered sentence
# 3  یافتمی     NOUN                 0
# 0    رشته  NOUN,EZ                 1
# 2     سری  NOUN,EZ                 1
# 1    خویش     PRON                 6
#      word      tag  ordered sentence
# 1       ز     NOUN                 0
# 4    وجود     NOUN                 0
# 2  تنگنای  NOUN,EZ                 1
# 3   زندان  NOUN,EZ                 1
# 0     چند      DET                 7
#      word      tag  ordered sentence
# 3     دری     NOUN                 0
# 4  یافتمی     NOUN                 0
# 1     سوی  NOUN,EZ                 1
# 2     عدم  NOUN,EZ                 1
# 0     کاش      ADV                 4
#     word      tag  ordered sentence
# 1  پیاله     NOUN                 0
# 2    سبو     NOUN                 0
# 3  دلجوی     NOUN                 0
# 0    گیر  NOUN,EZ                 1
#      word      tag  ordered sentence
# 2  کشتزار     NOUN                 0
# 0    فارغ  NOUN,EZ                 1
# 3      لب  NOUN,EZ                 1
# 1   بنشین      ADJ                 2
# 4     جوی      ADJ                 2
#     word      tag  ordered sentence
# 1    شخص  NOUN,EZ                 1
# 3    چرخ  NOUN,EZ                 1
# 2   عزیز      ADJ                 2
# 4  بدخوی      ADJ                 2
# 0     بس      ADV                 4
#     word   tag  ordered sentence
# 1    بار  NOUN                 0
# 2  پیاله  NOUN                 0
# 5    بار  NOUN                 0
# 6   سبوی  NOUN                 0
# 0     صد   NUM                 9
# 4     صد   NUM                 9
# 3    کرد  VERB                11
#     word      tag  ordered sentence
# 0   پیری     NOUN                 0
# 3  خماری     NOUN                 0
# 2  خانهٔ  NOUN,EZ                 1
# 1   دیدم     VERB                11
#      word      tag  ordered sentence
# 2  رفتگان  NOUN,EZ                 1
# 3  اخباری      ADJ                 2
# 0    گفتم     VERB                11
# 1    نکنی     VERB                11
#      word   tag  ordered sentence
# 1      می  NOUN                 0
# 5  بسیاری   ADJ                 2
# 3    همچو   ADV                 4
# 4      ما  PRON                 6
# 0    گفتا  VERB                11
# 2     خور  VERB                11
#     word   tag  ordered sentence
# 1    خبر  NOUN                 0
# 4   باری  NOUN                 0
# 2    باز   ADJ                 2
# 0  رفتند  VERB                11
# 3  نیامد  VERB                11
#    word   tag  ordered sentence
# 1  حدیث  NOUN                 0
# 4  ساقی  NOUN                 0
# 0   چند   DET                 7
# 2   پنج   NUM                 9
# 3   چار   NUM                 9
#    word   tag  ordered sentence
# 0  مشکل  NOUN                 0
# 6  ساقی  NOUN                 0
# 1    چه   DET                 7
# 3    چه   DET                 7
# 2   یکی   NUM                 9
# 4    صد   NUM                 9
# 5  هزار   NUM                 9
#     word     tag  ordered sentence
# 0  خاکیم    NOUN                 0
# 2    چنگ    NOUN                 0
# 4   ساقی    NOUN                 0
# 1    همه  DET,EZ                 8
# 3   بساز    VERB                11
#     word     tag  ordered sentence
# 2   باده    NOUN                 0
# 4   ساقی    NOUN                 0
# 1    همه  DET,EZ                 8
# 0  بادیم    VERB                11
# 3   بیار    VERB                11
#      word   tag  ordered sentence
# 1    نگاه  NOUN                 0
# 4    سویی  NOUN                 0
# 0   چندان   ADV                 4
# 3      هر   DET                 7
# 2  می‌کنم  VERB                11
#    word      tag  ordered sentence
# 4  جویی     NOUN                 0
# 0   باغ  NOUN,EZ                 1
# 3  کوثر  NOUN,EZ                 1
# 1  روان      ADJ                 2
# 2   است     VERB                11
#    word      tag  ordered sentence
# 0  صحرا     NOUN                 0
# 2  بهشت     NOUN                 0
# 4  کوثر     NOUN                 0
# 6   گوی  NOUN,EZ                 1
# 5    کم      ADJ                 2
# 1    چو      ADV                 4
# 3   است     VERB                11
#     word   tag  ordered sentence
# 1   بهشت  NOUN                 0
# 2  بهشتی  NOUN                 0
# 3   رویی  NOUN                 0
# 0  بنشین  VERB                11
#        word      tag  ordered sentence
# 5        دی     NOUN                 0
# 3     سودای  NOUN,EZ                 1
# 0       خوش      ADJ                 2
# 4        تو     PRON                 6
# 1       باش     VERB                11
# 2  پخته‌اند     VERB                11
#       word      tag  ordered sentence
# 4       دی     NOUN                 0
# 2    تمنای  NOUN,EZ                 1
# 0     فارغ      ADJ                 2
# 3       تو     PRON                 6
# 1  شده‌اند     VERB                11
#      word      tag  ordered sentence
# 0     قصه     NOUN                 0
# 1      چه     NOUN                 0
# 5      دی     NOUN                 0
# 3  تقاضای  NOUN,EZ                 1
# 4      تو     PRON                 6
# 2     کنم     VERB                11
#     word      tag  ordered sentence
# 5     دی     NOUN                 0
# 1   قرار  NOUN,EZ                 1
# 2    کار  NOUN,EZ                 1
# 3  فردای  NOUN,EZ                 1
# 4     تو     PRON                 6
# 0  دادند     VERB                11
#        word      tag  ordered sentence
# 1  کوزه‌گری     NOUN                 0
# 3       رای     NOUN                 0
# 0     کارگه  NOUN,EZ                 1
# 2      کردم     VERB                11
#     word      tag  ordered sentence
# 1    چرخ     NOUN                 0
# 3  استاد     NOUN                 0
# 0   پایه  NOUN,EZ                 1
# 2   دیدم     VERB                11
# 4   بپای     VERB                11
#     word      tag  ordered sentence
# 2   کوزه     NOUN                 0
# 3   دسته     NOUN                 0
# 4     سر     NOUN                 0
# 0  میکرد  NOUN,EZ                 1
# 1   دلیر      ADJ                 2
#      word      tag  ordered sentence
# 1  پادشاه     NOUN                 0
# 0     کله  NOUN,EZ                 1
# 2     دست  NOUN,EZ                 1
# 3    گدای  NOUN,EZ                 1
#      word      tag  ordered sentence
# 1     دلم     NOUN                 0
# 0     گوش  NOUN,EZ                 1
# 3     فلک  NOUN,EZ                 1
# 4  پنهانی      ADJ                 2
# 2     گفت     VERB                11
#       word   tag  ordered sentence
# 0     حکمی  NOUN                 0
# 1      قضا  NOUN                 0
# 3       من  PRON                 6
# 2      بود  VERB                11
# 4  می‌دانی  VERB                11
#    word      tag  ordered sentence
# 0  گردش  NOUN,EZ                 1
# 3   دست  NOUN,EZ                 1
# 4   بدی      ADJ                 2
# 1  خویش     PRON                 6
# 2   مرا     PRON                 6
#        word   tag  ordered sentence
# 2  سرگردانی  NOUN                 0
# 0       خود  PRON                 6
# 1  برهاندمی  VERB                11
#     word   tag  ordered sentence
# 0  کوزهٔ  NOUN                 0
# 1     می  NOUN                 0
# 4   ضرری  NOUN                 0
# 3     وی  PRON                 6
# 2   نیست  VERB                11
#    word   tag  ordered sentence
# 2  قدحی  NOUN                 0
# 6  دگری  NOUN                 0
# 0    پر   ADJ                 2
# 4    من  PRON                 6
# 5    ده   NUM                 9
# 1    کن  VERB                11
# 3  بخور  VERB                11
#      word   tag  ordered sentence
# 1     صنم  NOUN                 0
# 2  رهگذری  NOUN                 0
# 0   پیشتر   ADV                 4
#        word      tag  ordered sentence
# 3     کوزه‌     NOUN                 0
# 5  کوزه‌گری     NOUN                 0
# 0       خاک  NOUN,EZ                 1
# 1        من     PRON                 6
# 2        تو     PRON                 6
# 4       کند     VERB                11
#      word   tag  ordered sentence
# 0   آمدنم  NOUN                 0
# 3  نامدمی  NOUN                 0
# 1     خود  PRON                 6
# 2    بُدی  VERB                11
#    word   tag  ordered sentence
# 0   شدن  NOUN                 0
# 3    کی   ADV                 4
# 1    من  PRON                 6
# 2  بُدی  VERB                11
# 4  شدمی  VERB                11
#      word   tag  ordered sentence
# 4    خراب   ADJ                 2
# 3     دیر   ADV                 4
# 0     زان  PRON                 6
# 2     این  PRON                 6
# 1  نَبُدی  VERB                11
#      word   tag  ordered sentence
# 1   آمدمی  NOUN                 0
# 3    شدمی  NOUN                 0
# 5  بُدَمی  NOUN                 0
# 0      نه   ADV                 4
# 2      نه   ADV                 4
# 4      نه   ADV                 4
#    word      tag  ordered sentence
# 0   دست     NOUN                 0
# 3  گندم     NOUN                 0
# 4  نانی     NOUN                 0
# 2   مغز  NOUN,EZ                 1
# 1   دهد     VERB                11
#       word      tag  ordered sentence
# 2      منی     NOUN                 0
# 3  گوسفندی     NOUN                 0
# 4     رانی     NOUN                 0
# 0       می  NOUN,EZ                 1
# 1       دو      NUM                 9
#        word      tag  ordered sentence
# 0  لاله‌رخی     NOUN                 0
# 2    بستانی     NOUN                 0
# 1      گوشه  NOUN,EZ                 1
#      word      tag  ordered sentence
# 0    عیشی     NOUN                 0
# 6  سلطانی     NOUN                 0
# 4      حد  NOUN,EZ                 1
# 3      نه      ADV                 4
# 2      آن     PRON                 6
# 5      هر      DET                 7
# 1     بود     VERB                11
#      word      tag  ordered sentence
# 1     فلک     NOUN                 0
# 2     عدل     NOUN                 0
# 4    بُدی     NOUN                 0
# 0     کار  NOUN,EZ                 1
# 3  سنجیده     VERB                11
#       word      tag  ordered sentence
# 1      فلک     NOUN                 0
# 4      بدی     NOUN                 0
# 0    احوال  NOUN,EZ                 1
# 2     جمله  NOUN,EZ                 1
# 3  پسندیده   ADJ,EZ                 3
#     word      tag  ordered sentence
# 2  کارها     NOUN                 0
# 3  گردون     NOUN                 0
# 0    عدل  NOUN,EZ                 1
# 1    بدی      ADJ                 2
#      word      tag  ordered sentence
# 3     فضل     NOUN                 0
# 1    خاطر  NOUN,EZ                 1
# 2     اهل  NOUN,EZ                 1
# 0      کی      ADV                 4
# 4  رنجیده     VERB                11
# 5    بُدی     VERB                11
#        word   tag  ordered sentence
# 2    هشیاری  NOUN                 0
# 0  کوزه‌گرا   ADJ                 2
# 1      بپای  VERB                11
#     word      tag  ordered sentence
# 3   مردم     NOUN                 0
# 2     گل  NOUN,EZ                 1
# 0    چند      DET                 7
# 1    کنی     VERB                11
# 4  خواری     VERB                11
#      word      tag  ordered sentence
# 1  فریدون     NOUN                 0
# 3  کیخسرو     NOUN                 0
# 0   انگشت  NOUN,EZ                 1
# 2      کف  NOUN,EZ                 1
#         word   tag  ordered sentence
# 0        چرخ  NOUN                 0
# 2         چه   ADV                 4
# 1   نهاده‌ای  VERB                11
# 3  می‌پنداری  VERB                11
#      word      tag  ordered sentence
# 1    صبوح     NOUN                 0
# 2     صنم     NOUN                 0
# 3       ِ     NOUN                 0
# 4  فرخ‌پی     NOUN                 0
# 0   هنگام  NOUN,EZ                 1
#        word      tag  ordered sentence
# 1  ترانه‌ای     NOUN                 0
# 3        می     NOUN                 0
# 2   پیش‌آور  NOUN,EZ                 1
# 0     برساز     VERB                11
#        word      tag  ordered sentence
# 0    کافکند     NOUN                 0
# 3        جم     NOUN                 0
# 1       خاک  NOUN,EZ                 1
# 2  صدهزاران  NOUN,EZ                 1
# 4        کی      ADV                 4
#     word      tag  ordered sentence
# 2  تیرمه     NOUN                 0
# 4     دی     NOUN                 0
# 1   آمدن  NOUN,EZ                 1
# 3   رفتن  NOUN,EZ                 1
# 0    این      DET                 7
